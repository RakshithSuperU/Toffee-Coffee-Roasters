# %%
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import pandas as pd
import psycopg2
import calendar
import random
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings("ignore")

### Note : Cancelled orders shouldn't be considered for the analysis.

# %%
conn = psycopg2.connect(
    host='shopify-merchant-dump.ccm9mnr5avgs.ap-south-1.rds.amazonaws.com',
    port='5432',
    user='toffee_coffee_roasters_69e3f806d0674953afe3d3fb2f724c7c',
    password='toffee_coffee_roasters_69e3f806d0674953afe3d3fb2f724c7c_password',
    database='toffee_coffee_roasters_69e3f806d0674953afe3d3fb2f724c7c_db'
)

# %%
query1 = """select o.id as order_id,
            o.created_at::date as order_date,
            o.customer_id as user_id,
            oli.product_id as product_id,
            o.total_price as order_amount,
            oli.name as product_name,
            CASE
        WHEN cancelled_at IS NOT NULL THEN 'Cancelled'
         ELSE 'Delivered'
     END as order_status,
            oli.quantity as quantity,
            oli.price as sp
            from orders o
            join order_line_item oli on oli.order_id = o.id"""

# %%
data = pd.read_sql(query1, conn)

# %%
data["order_date"] = pd.to_datetime(data["order_date"])

# %%
data['WeekCount']=data['order_date'].dt.strftime('%y-w%U')

# %%
data = data.dropna()

# %%
#data = data[data['order_date'] >= '2021-01-01']

# %%
data=data.sort_values('order_date')
WeekList=data['WeekCount'].unique()

# %%
#data = data[data['order_date'] <= '2023-06-30']

# %%
WeekList = WeekList.tolist()
output_list = []

for i in range(len(WeekList) - 1):
    output_list.append(WeekList[i])
    current_week = int(WeekList[i].split('-w')[1])
    next_week = int(WeekList[i + 1].split('-w')[1])
    missing_weeks = next_week - current_week - 1
    for j in range(1, missing_weeks + 1):
        missing_week = current_week + j
        output_list.append(f'{WeekList[i][:5]}w{missing_week:02d}')

output_list.append(WeekList[-1])

# %%
orderuserlevel=data.groupby(['order_id','user_id']).agg(
          order_date=pd.NamedAgg(column='order_date', aggfunc='min'),

    ).reset_index()
orderuserlevel=orderuserlevel.sort_values('order_date')
orderuserlevel['TrxnRank'] = orderuserlevel.groupby('user_id')['order_date'].rank(method='first')
orderuserlevel


data=pd.merge(data,
         orderuserlevel[['order_id','TrxnRank']],
         on="order_id",
         how ='left')
data['New']=0
data['Repeat']=0
data.loc[data['TrxnRank']==1,'New']=1
data.loc[data['TrxnRank']>1,'Repeat']=1

#AOV Contribution
data['ordervalue']=data['quantity']*data['sp']
data['AOVContribution']=data['ordervalue']/data["order_id"].nunique()
data['DeltaDaysinOrders']=(data.groupby('user_id').order_date.shift() - data.order_date).dt.days.abs()
data['DeltaOrderValues']=(data.groupby('user_id').ordervalue.shift() - data.ordervalue)

# %%
data = data[data['order_status'] != 'Cancelled']

# %%
avg_delta_days = data["DeltaDaysinOrders"].mean() # change
weeklyusersegsats = {}
for x in output_list:
  x3 = data[data['WeekCount'] <= x]
  try:
    userweeklydata = x3.groupby("user_id").agg(
          Last_Date=pd.NamedAgg(column='order_date', aggfunc= lambda x: x.nlargest(1).min()),
          First_Date=pd.NamedAgg(column='order_date', aggfunc='min'),
          OrdersCount=pd.NamedAgg(column='order_id', aggfunc='nunique'),
          Frequency=pd.NamedAgg(column='order_id', aggfunc='nunique'),
          Order_Value=pd.NamedAgg(column='ordervalue', aggfunc='sum'),
          Mean_Days_Delta=pd.NamedAgg(column='DeltaDaysinOrders', aggfunc='mean'),
          Mean_OV_Delta=pd.NamedAgg(column='DeltaOrderValues', aggfunc='mean')
          ).reset_index()

    globalmaxdateweek=x3['order_date'].max()
    userweeklydata['Recency']=globalmaxdateweek-userweeklydata['Last_Date']
    userweeklydata['Recency']=userweeklydata['Recency'].dt.days.abs()
    userweeklydata['Activated_Quater']=userweeklydata['First_Date'].dt.to_period('Q')
    userweeklydata['MaturityAge']=np.nan
    userweeklydata.loc[userweeklydata['Frequency']>1,"MaturityAge"]=(userweeklydata['Last_Date']-userweeklydata['First_Date']).dt.days.abs()
    userweeklydata['Mean_Days_Delta']=userweeklydata['Mean_Days_Delta'].fillna(0)
    userweeklydata['Mean_OV_Delta']=userweeklydata['Mean_OV_Delta'].fillna(0)
    userweeklydata['Customer_AOV']=userweeklydata['Order_Value']/userweeklydata['OrdersCount']

    r_labels, f_labels,AOV_labels, m_labels,DelAOV_labels = range(4, 0, -1), range(1,5), range(1,5),range(1,5),range(1,5)
    userweeklydata['f_score'] = userweeklydata['OrdersCount'].transform(lambda x: pd.qcut(x.rank(method='first'), q = [0, 0.25, 0.5, 0.75, 1], labels = f_labels)).astype('int64')
    userweeklydata['r_score'] = userweeklydata['Recency'].transform(lambda x: pd.qcut(x.rank(method='first'), q = [0, 0.25, 0.5, 0.75, 1], labels = r_labels)).astype('int64')
    userweeklydata['AOV_score'] = userweeklydata['Customer_AOV'].transform(lambda x: pd.qcut(x.rank(method='first'), q = [0, 0.25, 0.5, 0.75, 1], labels = AOV_labels)).astype('int64')
    userweeklydata['m_score']=0
    userweeklydata.loc[userweeklydata['MaturityAge'].notnull(),'m_score']= userweeklydata.loc[userweeklydata['MaturityAge'].notnull()]['MaturityAge'].transform(lambda x: pd.qcut(x.rank(method='first'), q = [0, 0.25, 0.5, 0.75, 1], labels = m_labels)).astype('int64')
    userweeklydata['DelAOV'] = userweeklydata['Mean_OV_Delta'].transform(lambda x: pd.qcut(x.rank(method='first'), q = [0, 0.25, 0.5, 0.75, 1], labels = DelAOV_labels)).astype('int64')
    userweeklydata['SumScore'] = userweeklydata['r_score'] + userweeklydata['m_score'] + userweeklydata['AOV_score']+ userweeklydata['DelAOV'] +userweeklydata['f_score']

    def CohortLables_3(df):
      if ((df['Frequency']==1) & (df['r_score']>2)):
          return "New"
      elif ((df['Frequency'] == 1) & (df['r_score'] <= 2)):
          return 'Churned (Single Use Only)'
      elif ((df['Frequency'] > 1) & (df['m_score'] < 3) & (df['r_score'] >2)):
          return 'Recent & Loyals'
      elif ((df['Frequency'] > 1) & (df['m_score'] >=2) & (df['Recency'] <= avg_delta_days)): # change is there
          return 'Champions'
      else:
          return 'Churned (Repeat Use)'
    userweeklydata['CohortLabel'] = userweeklydata.apply(CohortLables_3, axis=1)

    usersegstats=userweeklydata.groupby(
      'CohortLabel'
    ).agg(
          Users=pd.NamedAgg(column='user_id', aggfunc='nunique'),
          Orders=pd.NamedAgg(column='OrdersCount', aggfunc='sum'),
          Recency=pd.NamedAgg(column='Recency', aggfunc='mean'),
          OrderValue=pd.NamedAgg(column='Order_Value', aggfunc='sum'),
          MeanDaysDelta=pd.NamedAgg(column='Mean_Days_Delta', aggfunc='mean'),
          MeanOVDelta=pd.NamedAgg(column='Mean_OV_Delta', aggfunc='mean'),
          Maturity=pd.NamedAgg(column='MaturityAge', aggfunc='mean'),
    )

    usersegstats["Frequency"] = usersegstats["Orders"] / usersegstats["Users"]
    usersegstats["AOVContribution"] = usersegstats["OrderValue"] / usersegstats["Orders"].sum()
    usersegstats["AOV"] = usersegstats["OrderValue"] / usersegstats["Orders"]
    user_cohort_labels = ['New', 'Churned (Single Use Only)', 'Recent & Loyals', 'Champions', 'Churned (Repeat Use)']
    var_list = ['Users', 'Orders', 'Recency', 'AOVContribution', 'OrderValue','MeanDaysDelta', 'MeanOVDelta', 'Maturity', 'Frequency', 'AOV']
    dummy_df = pd.DataFrame(index=user_cohort_labels, columns=var_list)
    for i in user_cohort_labels:
      try:
        dummy_df.loc[i] = usersegstats.loc[i]
      except:
        pass
    dummy_df = dummy_df.fillna(0)
    usersegstats = dummy_df
    print(usersegstats)
    weeklyusersegsats[x] = usersegstats
  except:
    pass
# Out:
#                            Users  Orders   Recency  AOVContribution  \
# New                        306.0   306.0  1.486928       270.523810
# Churned (Single Use Only)  328.0   328.0  2.658537       289.727891
# Recent & Loyals             12.0    25.0  1.500000        22.108844
# Champions                   24.0    66.0  1.750000        66.930612
# Churned (Repeat Use)         4.0    10.0  2.000000         8.843537
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta  Maturity  \
# New                          198835.0       0.000000     0.000000  0.000000
# Churned (Single Use Only)    212950.0       0.000000     0.000000  0.000000
# Recent & Loyals               16250.0       0.000000     0.000000  0.000000
# Champions                     49194.0       1.171627     6.244048  1.291667
# Churned (Repeat Use)           6500.0       0.000000     0.000000  0.000000
#
#                            Frequency         AOV
# New                         1.000000  649.787582
# Churned (Single Use Only)   1.000000  649.237805
# Recent & Loyals             2.083333  650.000000
# Champions                   2.750000  745.363636
# Churned (Repeat Use)        2.500000  650.000000
#                            Users  Orders   Recency  AOVContribution  \
# New                        323.0   323.0  6.773994       341.071264
# Churned (Single Use Only)  375.0   375.0  9.576000       279.885057
# Recent & Loyals             26.0    63.0  7.230769        54.303448
# Champions                   36.0    87.0  4.416667       114.435632
# Churned (Repeat Use)         8.0    22.0  9.000000        16.436782
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta  Maturity  \
# New                          296732.0       0.000000     0.000000  0.000000
# Churned (Single Use Only)    243500.0       0.000000     0.000000  0.000000
# Recent & Loyals               47244.0       1.413462  -171.471154  1.769231
# Champions                     99559.0       4.359788  -894.286376  5.055556
# Churned (Repeat Use)          14300.0       0.000000     0.000000  0.000000
#
#                            Frequency          AOV
# New                         1.000000   918.674923
# Churned (Single Use Only)   1.000000   649.333333
# Recent & Loyals             2.423077   749.904762
# Champions                   2.416667  1144.356322
# Churned (Repeat Use)        2.750000   650.000000
#                            Users  Orders    Recency  AOVContribution  \
# New                        339.0   339.0  12.648968       370.506652
# Churned (Single Use Only)  391.0   391.0  16.552430       281.485588
# Recent & Loyals             26.0    63.0  14.230769        52.376940
# Champions                   36.0    87.0  11.416667       110.375831
# Churned (Repeat Use)         8.0    22.0  16.000000        15.853659
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta  Maturity  \
# New                          334197.0       0.000000    -3.020649  0.000000
# Churned (Single Use Only)    253900.0       0.000000     0.000000  0.000000
# Recent & Loyals               47244.0       1.413462  -171.471154  1.769231
# Champions                     99559.0       4.359788  -894.286376  5.055556
# Churned (Repeat Use)          14300.0       0.000000     0.000000  0.000000
#
#                            Frequency          AOV
# New                         1.000000   985.831858
# Churned (Single Use Only)   1.000000   649.360614
# Recent & Loyals             2.423077   749.904762
# Champions                   2.416667  1144.356322
# Churned (Repeat Use)        2.750000   650.000000
#                            Users  Orders    Recency  AOVContribution  \
# New                        354.0   354.0  17.641243       369.383807
# Churned (Single Use Only)  410.0   410.0  23.526829       279.968454
# Recent & Loyals             29.0    70.0  19.137931        58.874869
# Champions                   37.0    93.0  16.702703       110.050473
# Churned (Repeat Use)         9.0    24.0  23.000000        16.403785
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta  Maturity  \
# New                          351284.0       0.000000    -2.892655  0.000000
# Churned (Single Use Only)    266250.0       0.000000     0.000000  0.000000
# Recent & Loyals               55990.0       1.353448  -135.646552  1.758621
# Champions                    104658.0       4.862613  -874.970721  6.243243
# Churned (Repeat Use)          15600.0       0.000000     0.000000  0.000000
#
#                            Frequency          AOV
# New                         1.000000   992.327684
# Churned (Single Use Only)   1.000000   649.390244
# Recent & Loyals             2.413793   799.857143
# Champions                   2.513514  1125.354839
# Churned (Repeat Use)        2.666667   650.000000
#                            Users  Orders    Recency  AOVContribution  \
# New                        400.0   400.0  18.070000       365.444444
# Churned (Single Use Only)  463.0   463.0  30.442765       278.365741
# Recent & Loyals             32.0    77.0  21.250000        62.576852
# Champions                   45.0   114.0  21.044444       116.370370
# Churned (Repeat Use)        10.0    26.0  30.000000        15.648148
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta  Maturity  \
# New                          394680.0       0.000000    -2.360000  0.000000
# Churned (Single Use Only)    300635.0       0.000000     0.000000  0.000000
# Recent & Loyals               67583.0       1.132812   -60.492188  1.531250
# Champions                    125680.0       7.322658  -737.617429  8.622222
# Churned (Repeat Use)          16900.0       0.000000     0.000000  0.000000
#
#                            Frequency          AOV
# New                         1.000000   986.700000
# Churned (Single Use Only)   1.000000   649.319654
# Recent & Loyals             2.406250   877.701299
# Champions                   2.533333  1102.456140
# Churned (Repeat Use)        2.600000   650.000000
#                            Users  Orders    Recency  AOVContribution  \
# New                        479.0   479.0  12.897704       422.405147
# Churned (Single Use Only)  569.0   569.0  37.142355       271.716912
# Recent & Loyals             45.0   103.0  21.111111        80.079412
# Champions                   63.0   166.0  12.206349       145.947794
# Churned (Repeat Use)        18.0    43.0  36.555556        20.551471
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta   Maturity  \
# New                          574471.0       0.000000    -1.970772   0.000000
# Churned (Single Use Only)    369535.0       0.000000     0.000000   0.000000
# Recent & Loyals              108908.0       2.183333  -326.627778   2.666667
# Champions                    198489.0      17.793168  -506.248693  22.206349
# Churned (Repeat Use)          27950.0       0.222222     0.000000   0.222222
#
#                            Frequency          AOV
# New                         1.000000  1199.313152
# Churned (Single Use Only)   1.000000   649.446397
# Recent & Loyals             2.288889  1057.359223
# Champions                   2.634921  1195.716867
# Churned (Repeat Use)        2.388889   650.000000
#                            Users  Orders    Recency  AOVContribution  \
# New                        523.0   523.0  14.604207       407.743675
# Churned (Single Use Only)  618.0   618.0  43.836570       286.788948
# Recent & Loyals             48.0   107.0  24.708333        80.059254
# Champions                   65.0   178.0  10.046154       138.192410
# Churned (Repeat Use)        33.0    76.0  42.333333        38.476698
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta   Maturity  \
# New                          612431.0       0.000000    -1.804971   0.000000
# Churned (Single Use Only)    430757.0       0.000000     0.000000   0.000000
# Recent & Loyals              120249.0       2.494792  -372.817708   2.937500
# Champions                    207565.0      19.553379  -266.158989  25.076923
# Churned (Repeat Use)          57792.0       1.545455  -222.515152   1.787879
#
#                            Frequency          AOV
# New                         1.000000  1170.996176
# Churned (Single Use Only)   1.000000   697.017799
# Recent & Loyals             2.229167  1123.822430
# Champions                   2.738462  1166.095506
# Churned (Repeat Use)        2.303030   760.421053
#                            Users  Orders    Recency  AOVContribution  \
# New                        590.0   590.0  17.291525       440.760417
# Churned (Single Use Only)  641.0   641.0  50.616225       287.814951
# Recent & Loyals             27.0    57.0  15.814815        41.187500
# Champions                   80.0   214.0  13.987500       151.130515
# Churned (Repeat Use)        56.0   130.0  47.964286        71.702819
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta   Maturity  \
# New                          719321.0       0.000000    -3.131356   0.000000
# Churned (Single Use Only)    469714.0       0.000000     0.000000   0.000000
# Recent & Loyals               67218.0       0.851852   104.537037   1.037037
# Champions                    246645.0      19.697537  -201.289596  25.450000
# Churned (Repeat Use)         117019.0       2.656250  -501.084821   3.089286
#
#                            Frequency          AOV
# New                         1.000000  1219.188136
# Churned (Single Use Only)   1.000000   732.783151
# Recent & Loyals             2.111111  1179.263158
# Champions                   2.675000  1152.546729
# Churned (Repeat Use)        2.321429   900.146154
#                            Users  Orders    Recency  AOVContribution  \
# New                        648.0   648.0  17.046296       418.770293
# Churned (Single Use Only)  718.0   718.0  55.949861       315.656543
# Recent & Loyals             36.0    78.0  17.611111        49.441193
# Champions                   91.0   235.0  18.164835       146.173385
# Churned (Repeat Use)        57.0   132.0  54.701754        65.333517
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta   Maturity  \
# New                          758393.0       0.000000     0.787809   0.000000
# Churned (Single Use Only)    571654.0       0.000000    -1.488858   0.000000
# Recent & Loyals               89538.0       1.231481   111.884259   1.583333
# Champions                    264720.0      22.126040  -199.703307  27.318681
# Churned (Repeat Use)         118319.0       2.609649  -492.293860   3.035088
#
#                            Frequency          AOV
# New                         1.000000  1170.359568
# Churned (Single Use Only)   1.000000   796.175487
# Recent & Loyals             2.166667  1147.923077
# Champions                   2.582418  1126.468085
# Churned (Repeat Use)        2.315789   896.356061
#                            Users  Orders    Recency  AOVContribution  \
# New                        721.0   721.0  18.044383       431.888667
# Churned (Single Use Only)  790.0   790.0  60.502532       312.432351
# Recent & Loyals             40.0    88.0  18.875000        49.916625
# Champions                   98.0   239.0  20.979592       131.151273
# Churned (Repeat Use)        65.0   165.0  58.815385        78.023964
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta   Maturity  \
# New                          865073.0       0.000000     1.456311   0.000000
# Churned (Single Use Only)    625802.0       0.000000    -1.251899   0.000000
# Recent & Loyals               99983.0       1.733333    73.220833   2.225000
# Champions                    262696.0      23.812415  -164.304932  29.551020
# Churned (Repeat Use)         156282.0       3.063122  -416.705656   4.030769
#
#                            Frequency          AOV
# New                         1.000000  1199.823856
# Churned (Single Use Only)   1.000000   792.154430
# Recent & Loyals             2.200000  1136.170455
# Champions                   2.438776  1099.146444
# Churned (Repeat Use)        2.538462   947.163636
#                            Users  Orders    Recency  AOVContribution  \
# New                        785.0   785.0  18.705732       396.743037
# Churned (Single Use Only)  874.0   874.0  64.794050       337.137466
# Recent & Loyals             50.0   109.0  20.980000        57.358041
# Champions                   74.0   218.0  15.716216        91.818509
# Churned (Repeat Use)       101.0   240.0  56.910891       112.146002
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta   Maturity  \
# New                          883150.0       0.000000     2.814013   0.000000
# Churned (Single Use Only)    750468.0       0.000000    -1.131579   0.000000
# Recent & Loyals              127679.0       1.926667   -27.363333   2.400000
# Champions                    204388.0      27.996782   -27.875804  35.432432
# Churned (Repeat Use)         249637.0       9.761056  -385.943564  11.930693
#
#                            Frequency          AOV
# New                         1.000000  1125.031847
# Churned (Single Use Only)   1.000000   858.659039
# Recent & Loyals             2.180000  1171.366972
# Champions                   2.945946   937.559633
# Churned (Repeat Use)        2.376238  1040.154167
#                            Users  Orders    Recency  AOVContribution  \
# New                        888.0   888.0  18.621622       388.834602
# Churned (Single Use Only)  945.0   945.0  69.729101       334.991590
# Recent & Loyals             65.0   139.0  20.461538        65.991189
# Champions                   90.0   259.0  12.688889        98.268722
# Churned (Repeat Use)       112.0   266.0  61.839286       111.943933
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta   Maturity  \
# New                          970920.0       0.000000     4.180180   0.000000
# Churned (Single Use Only)    836474.0       0.000000    -1.046561   0.000000
# Recent & Loyals              164780.0       2.400000    41.966667   2.784615
# Champions                    245377.0      31.592725    36.441005  40.411111
# Churned (Repeat Use)         279524.0       9.896131  -398.658929  12.303571
#
#                            Frequency          AOV
# New                         1.000000  1093.378378
# Churned (Single Use Only)   1.000000   885.157672
# Recent & Loyals             2.138462  1185.467626
# Champions                   2.877778   947.401544
# Churned (Repeat Use)        2.375000  1050.842105
#                             Users  Orders    Recency  AOVContribution  \
# New                         948.0   948.0  20.181435       377.176841
# Churned (Single Use Only)  1015.0  1015.0  74.677833       340.459489
# Recent & Loyals              73.0   156.0  21.219178        65.465409
# Champions                    97.0   279.0  14.092784        97.710692
# Churned (Repeat Use)        127.0   305.0  65.496063       120.321865
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta   Maturity  \
# New                         1019509.0       0.000000     1.075422   0.000000
# Churned (Single Use Only)    920262.0       0.000000    -0.974384   0.000000
# Recent & Loyals              176953.0       2.673516    17.933790   3.000000
# Champions                    264112.0      33.006996    64.148012  42.237113
# Churned (Repeat Use)         325230.0      10.855906  -348.581102  13.905512
#
#                            Frequency          AOV
# New                         1.000000  1075.431435
# Churned (Single Use Only)   1.000000   906.662069
# Recent & Loyals             2.136986  1134.314103
# Champions                   2.876289   946.637993
# Churned (Repeat Use)        2.401575  1066.327869
#                             Users  Orders    Recency  AOVContribution  \
# New                        1022.0  1022.0  21.623288       366.331282
# Churned (Single Use Only)  1080.0  1080.0  79.525926       339.557607
# Recent & Loyals              72.0   155.0  19.888889        58.765128
# Champions                   107.0   310.0  13.579439        98.425641
# Churned (Repeat Use)        150.0   358.0  68.380000       128.663248
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta   Maturity  \
# New                         1071519.0       0.000000    -1.289628   0.000000
# Churned (Single Use Only)    993206.0       0.000000    -1.238889   0.000000
# Recent & Loyals              171888.0       2.652778   -61.844907   3.013889
# Champions                    287895.0      35.668336    68.036827  47.149533
# Churned (Repeat Use)         376340.0      11.484667  -249.808667  14.486667
#
#                            Frequency          AOV
# New                         1.000000  1048.453033
# Churned (Single Use Only)   1.000000   919.635185
# Recent & Loyals             2.152778  1108.954839
# Champions                   2.897196   928.693548
# Churned (Repeat Use)        2.386667  1051.229050
#                             Users  Orders    Recency  AOVContribution  \
# New                        1047.0  1047.0  23.982808       348.610102
# Churned (Single Use Only)  1117.0  1117.0  83.377798       356.619016
# Recent & Loyals              78.0   170.0  22.205128        59.969297
# Champions                   111.0   322.0  15.369369       100.268075
# Churned (Repeat Use)        157.0   373.0  71.872611       128.733906
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta   Maturity  \
# New                         1055940.0       0.000000    -1.216332   0.000000
# Churned (Single Use Only)   1080199.0       0.000000    -1.653984   0.000000
# Recent & Loyals              181647.0       2.935897   -59.865385   3.371795
# Champions                    303712.0      34.923381    68.987452  47.315315
# Churned (Repeat Use)         389935.0      12.166879  -247.419108  15.235669
#
#                            Frequency          AOV
# New                         1.000000  1008.538682
# Churned (Single Use Only)   1.000000   967.053715
# Recent & Loyals             2.179487  1068.511765
# Champions                   2.900901   943.204969
# Churned (Repeat Use)        2.375796  1045.402145
#                             Users  Orders    Recency  AOVContribution  \
# New                        1069.0  1069.0  24.406922       347.822366
# Churned (Single Use Only)  1137.0  1137.0  84.755497       357.574716
# Recent & Loyals              81.0   177.0  23.654321        62.123825
# Champions                   109.0   321.0  15.633028        96.746840
# Churned (Repeat Use)        161.0   381.0  72.968944       129.297569
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta   Maturity  \
# New                         1073032.0       0.000000    -1.055659   0.000000
# Churned (Single Use Only)   1103118.0       0.000000    -1.624890   0.000000
# Recent & Loyals              191652.0       3.090535   -55.882716   3.641975
# Champions                    298464.0      34.489253    61.325142  47.926606
# Churned (Repeat Use)         398883.0      12.963975  -233.520497  15.956522
#
#                            Frequency          AOV
# New                         1.000000  1003.771749
# Churned (Single Use Only)   1.000000   970.200528
# Recent & Loyals             2.185185  1082.779661
# Champions                   2.944954   929.794393
# Churned (Repeat Use)        2.366460  1046.937008
#                             Users  Orders    Recency  AOVContribution  \
# New                        1105.0  1105.0  27.168326       339.957617
# Churned (Single Use Only)  1193.0  1193.0  89.810562       355.137285
# Recent & Loyals              95.0   206.0  26.421053        66.983415
# Champions                   121.0   319.0  16.446281        92.352273
# Churned (Repeat Use)        167.0   433.0  77.982036       136.155405
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta   Maturity  \
# New                         1106902.0       0.000000    -1.220362   0.000000
# Churned (Single Use Only)   1156327.0       0.000000    -1.548617   0.000000
# Recent & Loyals              218098.0       3.698246   -47.715789   4.273684
# Champions                    300699.0      36.012652   133.601928  50.429752
# Churned (Repeat Use)         443322.0      14.733305  -241.603450  18.317365
#
#                            Frequency          AOV
# New                         1.000000  1001.721267
# Churned (Single Use Only)   1.000000   969.259849
# Recent & Loyals             2.168421  1058.728155
# Champions                   2.636364   942.630094
# Churned (Repeat Use)        2.592814  1023.838337
#                             Users  Orders    Recency  AOVContribution  \
# New                        1118.0  1118.0  33.288909       342.745438
# Churned (Single Use Only)  1202.0  1202.0  96.530782       354.178832
# Recent & Loyals              97.0   210.0  32.639175        68.855535
# Champions                   109.0   290.0  20.651376        82.236922
# Churned (Repeat Use)        181.0   468.0  81.475138       147.035888
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta   Maturity  \
# New                         1126947.0       0.000000    -2.292039   0.000000
# Churned (Single Use Only)   1164540.0       0.000000    -1.537022   0.000000
# Recent & Loyals              226397.0       3.902062   -25.388316   4.587629
# Champions                    270395.0      36.500284   152.518349  51.816514
# Churned (Repeat Use)         483454.0      15.986898  -209.667272  19.950276
#
#                            Frequency          AOV
# New                         1.000000  1008.002683
# Churned (Single Use Only)   1.000000   968.835275
# Recent & Loyals             2.164948  1078.080952
# Champions                   2.660550   932.396552
# Churned (Repeat Use)        2.585635  1033.021368
#                             Users  Orders     Recency  AOVContribution  \
# New                        1127.0  1127.0   38.992902       338.180848
# Churned (Single Use Only)  1217.0  1217.0  103.023007       349.618737
# Recent & Loyals              99.0   263.0   38.898990        79.382449
# Champions                    88.0   242.0   22.454545        68.979840
# Churned (Repeat Use)        205.0   524.0   82.853659       156.911355
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta   Maturity  \
# New                         1140684.0       0.000000    -2.081781   0.000000
# Churned (Single Use Only)   1179264.0       0.000000    -1.518077   0.000000
# Recent & Loyals              267757.0       3.854141   -24.679663   4.555556
# Champions                    232669.0      37.813799   172.818182  55.250000
# Churned (Repeat Use)         529262.0      18.405505  -174.041185  22.887805
#
#                            Frequency          AOV
# New                         1.000000  1012.141970
# Churned (Single Use Only)   1.000000   968.992605
# Recent & Loyals             2.656566  1018.087452
# Champions                   2.750000   961.442149
# Churned (Repeat Use)        2.556098  1010.041985
#                             Users  Orders     Recency  AOVContribution  \
# New                        1139.0  1139.0   44.798068       340.638742
# Churned (Single Use Only)  1228.0  1228.0  109.687296       350.686949
# Recent & Loyals              99.0   262.0   45.757576        80.155203
# Champions                    64.0   178.0   23.734375        52.149030
# Churned (Repeat Use)        231.0   595.0   84.216450       171.912992
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta   Maturity  \
# New                         1158853.0       0.000000    -2.998390   0.000000
# Churned (Single Use Only)   1193037.0       0.000000    -1.504479   0.000000
# Recent & Loyals              272688.0       4.037643   -13.528148   4.787879
# Champions                    177411.0      36.762202   192.709635  54.781250
# Churned (Repeat Use)         584848.0      20.861307  -144.793043  26.666667
#
#                            Frequency          AOV
# New                         1.000000  1017.430202
# Churned (Single Use Only)   1.000000   971.528502
# Recent & Loyals             2.646465  1040.793893
# Champions                   2.781250   996.691011
# Churned (Repeat Use)        2.575758   982.937815
#                             Users  Orders     Recency  AOVContribution  \
# New                        1160.0  1160.0   49.400000       349.689884
# Churned (Single Use Only)  1250.0  1250.0  116.014400       351.070520
# Recent & Loyals              99.0   262.0   50.393939        80.595087
# Champions                    56.0   157.0   25.053571        44.941329
# Churned (Repeat Use)        244.0   631.0   88.483607       179.711850
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta   Maturity  \
# New                         1209927.0       0.000000    -2.867529   0.000000
# Churned (Single Use Only)   1214704.0       0.000000    -1.446000   0.000000
# Recent & Loyals              278859.0       4.406330   -14.092121   5.212121
# Champions                    155497.0      40.093112   280.212798  60.821429
# Churned (Repeat Use)         621803.0      20.777440  -147.383304  27.147541
#
#                            Frequency          AOV
# New                         1.000000  1043.040517
# Churned (Single Use Only)   1.000000   971.763200
# Recent & Loyals             2.646465  1064.347328
# Champions                   2.803571   990.426752
# Churned (Repeat Use)        2.586066   985.424723
#                             Users  Orders     Recency  AOVContribution  \
# New                        1181.0  1181.0   53.548688       356.664395
# Churned (Single Use Only)  1274.0  1274.0  122.284144       352.291880
# Recent & Loyals             100.0   264.0   55.300000        81.169222
# Champions                    29.0    80.0   16.103448        25.557354
# Churned (Repeat Use)        277.0   723.0   88.920578       202.533220
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta   Maturity  \
# New                         1256172.0       0.000000     0.288879   0.000000
# Churned (Single Use Only)   1240772.0       0.000000    -1.418760   0.000000
# Recent & Loyals              285878.0       4.478933   -14.217867   5.330000
# Champions                     90013.0      43.709770   282.908046  72.413793
# Churned (Repeat Use)         713322.0      22.720793  -104.863211  30.296029
#
#                            Frequency          AOV
# New                         1.000000  1063.651143
# Churned (Single Use Only)   1.000000   973.918367
# Recent & Loyals             2.640000  1082.871212
# Champions                   2.758621  1125.162500
# Churned (Repeat Use)        2.610108   986.614108
#                             Users  Orders     Recency  AOVContribution  \
# New                        1199.0  1199.0   58.154295       358.056350
# Churned (Single Use Only)  1292.0  1292.0  128.736842       353.376227
# Recent & Loyals              99.0   262.0   61.858586        79.248668
# Champions                    28.0    76.0   15.750000        22.975049
# Churned (Repeat Use)        283.0   738.0   94.745583       206.045136
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta   Maturity  \
# New                         1277187.0       0.000000     0.084376   0.000000
# Churned (Single Use Only)   1260493.0       0.000000    -1.398994   0.000000
# Recent & Loyals              282680.0       4.473670   -14.361481   5.333333
# Champions                     81952.0      46.127976   125.160714  78.107143
# Churned (Repeat Use)         734963.0      22.873944   -80.896736  30.618375
#
#                            Frequency          AOV
# New                         1.000000  1065.210175
# Churned (Single Use Only)   1.000000   975.613777
# Recent & Loyals             2.646465  1078.931298
# Champions                   2.714286  1078.315789
# Churned (Repeat Use)        2.607774   995.884824
#                             Users  Orders     Recency  AOVContribution  \
# New                        1224.0  1224.0   61.895425       362.051891
# Churned (Single Use Only)  1317.0  1317.0  134.978740       355.556169
# Recent & Loyals             100.0   264.0   68.200000        82.403533
# Champions                    26.0    71.0   18.846154        21.530224
# Churned (Repeat Use)        286.0   747.0  101.041958       205.248413
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta   Maturity  \
# New                         1311714.0       0.000000     0.207244   0.000000
# Churned (Single Use Only)   1288180.0       0.000000    -1.372437   0.000000
# Recent & Loyals              298548.0       4.431790   -14.217867   5.300000
# Champions                     78004.0      43.500000   153.108974  79.923077
# Churned (Repeat Use)         743615.0      23.187329   -84.257959  31.157343
#
#                            Frequency          AOV
# New                         1.000000  1071.661765
# Churned (Single Use Only)   1.000000   978.116932
# Recent & Loyals             2.640000  1130.863636
# Champions                   2.730769  1098.647887
# Churned (Repeat Use)        2.611888   995.468541
#                             Users  Orders     Recency  AOVContribution  \
# New                        1248.0  1248.0   65.104968       363.448836
# Churned (Single Use Only)  1345.0  1345.0  141.124907       355.839199
# Recent & Loyals             101.0   266.0   73.930693        81.097185
# Champions                    29.0    81.0   15.482759        31.514348
# Churned (Repeat Use)        289.0   754.0  107.276817       202.667840
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta   Maturity  \
# New                         1342580.0       0.000000     1.270566   0.000000
# Churned (Single Use Only)   1314470.0       0.000000    -1.343866   0.000000
# Recent & Loyals              299573.0       4.863159   -12.666205   5.772277
# Champions                    116414.0      43.570115   162.190230  86.034483
# Churned (Repeat Use)         748655.0      23.336480   -79.957703  31.287197
#
#                            Frequency          AOV
# New                         1.000000  1075.785256
# Churned (Single Use Only)   1.000000   977.301115
# Recent & Loyals             2.633663  1126.214286
# Champions                   2.793103  1437.209877
# Churned (Repeat Use)        2.608997   992.911141
#                             Users  Orders     Recency  AOVContribution  \
# New                        1279.0  1279.0   68.110242       365.378981
# Churned (Single Use Only)  1371.0  1371.0  147.296864       356.986996
# Recent & Loyals             100.0   263.0   76.810000        80.239915
# Champions                    29.0    82.0   17.172414        30.569268
# Churned (Repeat Use)        296.0   773.0  113.391892       204.689756
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta   Maturity  \
# New                         1376748.0       0.000000    -0.737686   0.000000
# Churned (Single Use Only)   1345127.0       0.000000    -0.906637   0.000000
# Recent & Loyals              302344.0       4.944171    -7.593343   6.090000
# Champions                    115185.0      48.125287   204.739080  92.034483
# Churned (Repeat Use)         771271.0      23.254762   -84.007127  31.466216
#
#                            Frequency          AOV
# New                         1.000000  1076.425332
# Churned (Single Use Only)   1.000000   981.128373
# Recent & Loyals             2.630000  1149.596958
# Champions                   2.827586  1404.695122
# Churned (Repeat Use)        2.611486   997.763260
#                             Users  Orders     Recency  AOVContribution  \
# New                        1301.0  1301.0   72.131437       369.516087
# Churned (Single Use Only)  1390.0  1390.0  153.712230       356.852995
# Recent & Loyals              99.0   262.0   80.808081        81.357834
# Champions                    30.0    85.0   18.433333        31.902694
# Churned (Repeat Use)        301.0   785.0  119.604651       204.166885
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta   Maturity  \
# New                         1412660.0       0.000000     0.038560   0.000000
# Churned (Single Use Only)   1364249.0       0.000000    -0.894245   0.000000
# Recent & Loyals              311031.0       5.141058   -19.629639   6.484848
# Champions                    121964.0      47.794444   297.470000  91.500000
# Churned (Repeat Use)         780530.0      23.379268   -79.655403  31.903654
#
#                            Frequency          AOV
# New                         1.000000  1085.826287
# Churned (Single Use Only)   1.000000   981.474101
# Recent & Loyals             2.646465  1187.141221
# Champions                   2.833333  1434.870588
# Churned (Repeat Use)        2.607973   994.305732
#                             Users  Orders     Recency  AOVContribution  \
# New                        1329.0  1329.0   74.965388       371.842659
# Churned (Single Use Only)  1416.0  1416.0  159.934322       358.044148
# Recent & Loyals              99.0   261.0   86.484848        79.384754
# Champions                    34.0    96.0   15.911765        35.422741
# Churned (Repeat Use)        305.0   794.0  125.524590       202.841889
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta   Maturity  \
# New                         1448699.0       0.000000    -0.558942   0.000000
# Churned (Single Use Only)   1394940.0       0.000000    -0.122881   0.000000
# Recent & Loyals              309283.0       5.206715   -24.700346   6.595960
# Champions                    138007.0      46.747549   143.113235  87.176471
# Churned (Repeat Use)         790272.0      23.847518   -75.234239  32.704918
#
#                            Frequency          AOV
# New                         1.000000  1090.066968
# Churned (Single Use Only)   1.000000   985.127119
# Recent & Loyals             2.636364  1184.992337
# Champions                   2.823529  1437.572917
# Churned (Repeat Use)        2.603279   995.304786
#                             Users  Orders     Recency  AOVContribution  \
# New                        1348.0  1348.0   77.917656       376.337362
# Churned (Single Use Only)  1447.0  1447.0  166.024879       358.869335
# Recent & Loyals             104.0   272.0   90.000000        80.698892
# Champions                    40.0   117.0   15.925000        42.549345
# Churned (Repeat Use)        303.0   788.0  132.006601       198.715760
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta   Maturity  \
# New                         1494812.0       0.000000     0.832839   0.000000
# Churned (Single Use Only)   1425429.0       0.000000    -0.051140   0.000000
# Recent & Loyals              320536.0       5.227225   -24.267637   6.750000
# Champions                    169006.0      43.208333   -79.155833  88.150000
# Churned (Repeat Use)         789299.0      23.977754   -69.587820  33.118812
#
#                            Frequency          AOV
# New                         1.000000  1108.910979
# Churned (Single Use Only)   1.000000   985.092605
# Recent & Loyals             2.615385  1178.441176
# Champions                   2.925000  1444.495726
# Churned (Repeat Use)        2.600660  1001.648477
#                             Users  Orders     Recency  AOVContribution  \
# New                        1392.0  1392.0   79.125000       387.280098
# Churned (Single Use Only)  1481.0  1481.0  172.043214       357.166093
# Recent & Loyals             104.0   273.0   90.894231        79.279361
# Champions                    34.0   100.0   15.294118        29.508354
# Churned (Repeat Use)        317.0   824.0  135.618297       210.724570
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta   Maturity  \
# New                         1576230.0       0.000000     0.971863   0.000000
# Churned (Single Use Only)   1453666.0       0.000000     0.634706   0.000000
# Recent & Loyals              322667.0       5.397097     9.945504   7.019231
# Champions                    120099.0      43.690196  -181.806373  87.941176
# Churned (Repeat Use)         857649.0      24.108705   -65.182207  34.299685
#
#                            Frequency          AOV
# New                         1.000000  1132.349138
# Churned (Single Use Only)   1.000000   981.543552
# Recent & Loyals             2.625000  1181.930403
# Champions                   2.941176  1200.990000
# Churned (Repeat Use)        2.599369  1040.836165
#                             Users  Orders     Recency  AOVContribution  \
# New                        1434.0  1434.0   78.912831       391.804872
# Churned (Single Use Only)  1527.0  1527.0  177.647675       358.141151
# Recent & Loyals             107.0   279.0   93.373832        82.716026
# Champions                    42.0   123.0   13.880952        35.170289
# Churned (Repeat Use)        317.0   824.0  142.416404       203.850728
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta   Maturity  \
# New                         1640487.0       0.000000    -1.521734   0.000000
# Churned (Single Use Only)   1499537.0       0.000000     1.279633   0.000000
# Recent & Loyals              346332.0       6.033939    32.063854   7.794393
# Champions                    147258.0      50.338492  -191.976474  95.904762
# Churned (Repeat Use)         853523.0      24.573479   -74.630156  34.968454
#
#                            Frequency          AOV
# New                         1.000000  1143.993724
# Churned (Single Use Only)   1.000000   982.015062
# Recent & Loyals             2.607477  1241.333333
# Champions                   2.928571  1197.219512
# Churned (Repeat Use)        2.599369  1035.828883
#                             Users  Orders     Recency  AOVContribution  \
# New                        1486.0  1486.0   77.979139       395.795833
# Churned (Single Use Only)  1578.0  1578.0  183.185678       358.558333
# Recent & Loyals             108.0   280.0   93.212963        79.429861
# Champions                    47.0   139.0   15.553191        37.197222
# Churned (Repeat Use)        323.0   837.0  148.835913       201.443056
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta   Maturity  \
# New                         1709838.0       0.000000    -0.624271   0.000000
# Churned (Single Use Only)   1548972.0       0.000000     1.852345   0.000000
# Recent & Loyals              343137.0       6.552143    43.878078   8.305556
# Champions                    160692.0      52.660132  -173.983283  96.276596
# Churned (Repeat Use)         870234.0      24.257357   -75.911794  34.566563
#
#                            Frequency          AOV
# New                         1.000000  1150.631225
# Churned (Single Use Only)   1.000000   981.604563
# Recent & Loyals             2.592593  1225.489286
# Champions                   2.957447  1156.057554
# Churned (Repeat Use)        2.591331  1039.706093
#                             Users  Orders     Recency  AOVContribution  \
# New                        1526.0  1526.0   79.448886       395.343290
# Churned (Single Use Only)  1612.0  1612.0  189.187965       359.158407
# Recent & Loyals             108.0   280.0   97.111111        74.235121
# Champions                    53.0   159.0   16.735849        47.892736
# Churned (Repeat Use)        325.0   842.0  155.332308       194.486762
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta   Maturity  \
# New                         1747022.0       0.000000    -0.136249   0.000000
# Churned (Single Use Only)   1587121.0       0.000000     1.701613   0.000000
# Recent & Loyals              328045.0       6.382081    18.748448   8.296296
# Champions                    211638.0      51.026595  -134.869452  96.283019
# Churned (Repeat Use)         859437.0      24.685875   -74.199773  35.156923
#
#                            Frequency          AOV
# New                         1.000000  1144.837484
# Churned (Single Use Only)   1.000000   984.566377
# Recent & Loyals             2.592593  1171.589286
# Champions                   3.000000  1331.056604
# Churned (Repeat Use)        2.590769  1020.709026
#                             Users  Orders     Recency  AOVContribution  \
# New                        1599.0  1599.0   76.760475       407.954973
# Churned (Single Use Only)  1673.0  1673.0  194.496712       362.476721
# Recent & Loyals             104.0   270.0   96.817308        68.883060
# Champions                    50.0   150.0   16.320000        43.067541
# Churned (Repeat Use)        341.0   883.0  158.530792       200.013989
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta   Maturity  \
# New                         1866394.0       0.000000    -0.464636    0.00000
# Churned (Single Use Only)   1658331.0       0.000000     2.528990    0.00000
# Recent & Loyals              315140.0       6.467289     7.653837    8.50000
# Champions                    197034.0      55.859190    19.430048  100.48000
# Churned (Repeat Use)         915064.0      24.759852   -92.070654   36.01173
#
#                            Frequency          AOV
# New                         1.000000  1167.225766
# Churned (Single Use Only)   1.000000   991.231919
# Recent & Loyals             2.596154  1167.185185
# Champions                   3.000000  1313.560000
# Churned (Repeat Use)        2.589443  1036.312571
#                             Users  Orders     Recency  AOVContribution  \
# New                        1660.0  1660.0   75.177108       428.409274
# Churned (Single Use Only)  1733.0  1733.0  199.859781       361.530807
# Recent & Loyals             105.0   271.0   96.828571        67.923989
# Champions                    52.0   165.0   17.384615        43.888842
# Churned (Repeat Use)        347.0   894.0  163.919308       198.969511
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta    Maturity  \
# New                         2023377.0       0.000000    -0.128084    0.000000
# Churned (Single Use Only)   1707510.0       0.000000     2.415465    0.000000
# Recent & Loyals              320805.0       6.162839   -47.250803    8.057143
# Champions                    207287.0      57.138874   -70.198672  105.346154
# Churned (Repeat Use)         939733.0      24.792487   -91.242102   36.207493
#
#                            Frequency          AOV
# New                         1.000000  1218.901807
# Churned (Single Use Only)   1.000000   985.291402
# Recent & Loyals             2.580952  1183.782288
# Champions                   3.173077  1256.284848
# Churned (Repeat Use)        2.576369  1051.155481
#                             Users  Orders     Recency  AOVContribution  \
# New                        1743.0  1743.0   72.000574       439.440106
# Churned (Single Use Only)  1799.0  1799.0  205.087827       360.140940
# Recent & Loyals             108.0   273.0   88.018519        65.836892
# Champions                    52.0   158.0   17.576923        40.272117
# Churned (Repeat Use)        366.0   944.0  167.019126       203.367094
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta    Maturity  \
# New                         2160727.0       0.000000     1.677021    0.000000
# Churned (Single Use Only)   1770813.0       0.000000     1.205114    0.000000
# Recent & Loyals              323720.0       6.313408   -24.747694    8.416667
# Champions                    198018.0      59.102015  -144.238507  101.923077
# Churned (Repeat Use)         999956.0      25.154807   -82.021916   37.254098
#
#                            Frequency          AOV
# New                         1.000000  1239.659782
# Churned (Single Use Only)   1.000000   984.331851
# Recent & Loyals             2.527778  1185.787546
# Champions                   3.038462  1253.278481
# Churned (Repeat Use)        2.579235  1059.275424
#                             Users  Orders     Recency  AOVContribution  \
# New                        1813.0  1813.0   70.565361       446.945712
# Churned (Single Use Only)  1858.0  1858.0  210.469322       360.551141
# Recent & Loyals             110.0   277.0   83.818182        67.587136
# Champions                    51.0   160.0   17.058824        38.479347
# Churned (Repeat Use)        380.0   976.0  170.415789       203.477970
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta    Maturity  \
# New                         2272272.0       0.001103     4.230583    0.000000
# Churned (Single Use Only)   1833042.0       0.000000     0.803821    0.000000
# Recent & Loyals              343613.0       6.260740   -19.293190    8.490909
# Champions                    195629.0      58.609734  -146.190896  107.000000
# Churned (Repeat Use)        1034482.0      26.194279   -78.113214   38.178947
#
#                            Frequency          AOV
# New                         1.000000  1253.321566
# Churned (Single Use Only)   1.000000   986.567277
# Recent & Loyals             2.518182  1240.480144
# Champions                   3.137255  1222.681250
# Churned (Repeat Use)        2.568421  1059.920082
#                             Users  Orders     Recency  AOVContribution  \
# New                        1921.0  1921.0   64.116606       454.856159
# Churned (Single Use Only)  1956.0  1956.0  214.584867       357.055638
# Recent & Loyals             113.0   283.0   71.115044        65.716598
# Champions                    68.0   195.0   13.691176        36.701712
# Churned (Repeat Use)        392.0  1019.0  173.994898       204.455527
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta    Maturity  \
# New                         2444397.0       0.001041     3.153045    0.000000
# Churned (Single Use Only)   1918817.0       0.000000     0.142127    0.000000
# Recent & Loyals              353161.0       5.950721    11.573738    8.247788
# Champions                    197235.0      80.076155   -61.797356  127.397059
# Churned (Repeat Use)        1098744.0      26.266970   -73.837093   39.625000
#
#                            Frequency          AOV
# New                         1.000000  1272.460698
# Churned (Single Use Only)   1.000000   980.990286
# Recent & Loyals             2.504425  1247.918728
# Champions                   2.867647  1011.461538
# Churned (Repeat Use)        2.599490  1078.257115
#                             Users  Orders     Recency  AOVContribution  \
# New                        1977.0  1977.0   64.482549       454.394646
# Churned (Single Use Only)  2009.0  2009.0  220.171229       354.522879
# Recent & Loyals             122.0   302.0   67.032787        69.991319
# Champions                    69.0   202.0   16.072464        37.913547
# Churned (Repeat Use)        401.0  1039.0  179.057357       202.825647
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta    Maturity  \
# New                         2512348.0       0.001012     3.279801    0.000000
# Churned (Single Use Only)   1960157.0       0.000000     0.138377    0.000000
# Recent & Loyals              386982.0       5.738509     6.146850    8.409836
# Champions                    209624.0      77.511284   -51.157781  127.202899
# Churned (Repeat Use)        1121423.0      26.578726   -69.584515   40.052369
#
#                            Frequency          AOV
# New                         1.000000  1270.788063
# Churned (Single Use Only)   1.000000   975.687904
# Recent & Loyals             2.475410  1281.397351
# ...
# Churned (Repeat Use)        4485.0  14273.0  353.579487       386.976048
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta    Maturity  \
# New                         9957580.0       0.002119     2.490485    0.000000
# Churned (Single Use Only)  16655733.0       0.032821     0.550110    0.000000
# Recent & Loyals             3948397.0      16.152877   -45.671013   29.024051
# Champions                   4351211.0      60.976505   -18.980696  354.613636
# Churned (Repeat Use)       19856128.0      74.101444   -28.493751  222.475139
#
#                            Frequency          AOV
# New                         1.000000   703.417632
# Churned (Single Use Only)   1.000000  1064.060116
# Recent & Loyals             2.260289   933.647907
# Champions                   5.681818  1450.403667
# Churned (Repeat Use)        3.182386  1391.167099
#                              Users   Orders     Recency  AOVContribution  \
# New                        14316.0  14316.0   99.015018       189.033747
# Churned (Single Use Only)  15797.0  15797.0  533.996708       324.808538
# Recent & Loyals             1912.0   4320.0   91.225418        73.634093
# Champions                    567.0   3166.0   20.097002        88.988001
# Churned (Repeat Use)        4541.0  14406.0  358.013433       384.028805
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta    Maturity  \
# New                         9830700.0       0.002096     2.253002    0.000000
# Churned (Single Use Only)  16891668.0       0.032522     0.583288    0.000000
# Recent & Loyals             3829341.0      16.079902   -48.804326   27.914226
# Champions                   4627821.0      65.240284   -22.333488  356.560847
# Churned (Repeat Use)       19971418.0      73.182857   -28.069773  219.885708
#
#                            Frequency          AOV
# New                         1.000000   686.693210
# Churned (Single Use Only)   1.000000  1069.295942
# Recent & Loyals             2.259414   886.421528
# Champions                   5.583774  1461.724889
# Churned (Repeat Use)        3.172429  1386.326392
#                              Users   Orders     Recency  AOVContribution  \
# New                        14776.0  14776.0   96.437534       179.535139
# Churned (Single Use Only)  16149.0  16149.0  534.749149       327.587415
# Recent & Loyals             1940.0   4385.0   88.499485        69.033220
# Champions                    491.0   2744.0   20.331976        75.191084
# Churned (Repeat Use)        4714.0  15106.0  354.920238       394.283032
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta    Maturity  \
# New                         9544088.0       0.003485     2.342773    0.000000
# Churned (Single Use Only)  17414547.0       0.032680     0.448720    0.000000
# Recent & Loyals             3669806.0      16.188300   -49.418761   26.961340
# Champions                   3997158.0      64.435182    -7.739037  356.097760
# Churned (Repeat Use)       20960086.0      72.560460   -29.207727  220.375689
#
#                            Frequency          AOV
# New                         1.000000   645.918246
# Churned (Single Use Only)   1.000000  1078.366896
# Recent & Loyals             2.260309   836.899886
# Champions                   5.588595  1456.690233
# Churned (Repeat Use)        3.204497  1387.533828
#                              Users   Orders     Recency  AOVContribution  \
# New                        14745.0  14745.0   99.839878       176.116246
# Churned (Single Use Only)  16300.0  16300.0  538.848405       325.715161
# Recent & Loyals             2004.0   4524.0   91.253493        70.176636
# Champions                    606.0   3313.0   12.632013        91.807352
# Churned (Repeat Use)        4688.0  14952.0  360.322099       384.612513
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta    Maturity  \
# New                         9481042.0       0.003866     2.507154    0.000000
# Churned (Single Use Only)  17534550.0       0.032377     0.252487    0.000000
# Recent & Loyals             3777889.0      17.042509   -59.086591   28.174152
# Champions                   4942357.0      70.569516   -26.507556  359.734323
# Churned (Repeat Use)       20705230.0      72.797356   -28.852742  221.734642
#
#                            Frequency          AOV
# New                         1.000000   643.000475
# Churned (Single Use Only)   1.000000  1075.739264
# Recent & Loyals             2.257485   835.077144
# Champions                   5.466997  1491.807123
# Churned (Repeat Use)        3.189420  1384.779963
#                              Users   Orders     Recency  AOVContribution  \
# New                        14841.0  14841.0  100.705613       171.341979
# Churned (Single Use Only)  16553.0  16553.0  541.349544       324.336920
# Recent & Loyals             2087.0   4731.0   90.567322        69.290651
# Champions                    683.0   3563.0   13.292826        95.764841
# Churned (Repeat Use)        4724.0  15058.0  364.558637       379.941567
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta    Maturity  \
# New                         9380288.0       0.003841     2.171865    0.000000
# Churned (Single Use Only)  17756149.0       0.031882     0.233525    0.000000
# Recent & Loyals             3793386.0      17.591327   -59.472702   28.381888
# Champions                   5242742.0      76.579338   -28.402741  348.973646
# Churned (Repeat Use)       20800281.0      72.589582   -28.193330  221.293819
#
#                            Frequency          AOV
# New                         1.000000   632.052288
# Churned (Single Use Only)   1.000000  1072.684649
# Recent & Loyals             2.266890   801.814838
# Champions                   5.216691  1471.440359
# Churned (Repeat Use)        3.187553  1381.344202
#                              Users   Orders     Recency  AOVContribution  \
# New                        15372.0  15372.0   96.266003       162.504332
# Churned (Single Use Only)  16990.0  16990.0  540.930312       326.914839
# Recent & Loyals             2092.0   4743.0   87.167304        64.797215
# Champions                    703.0   3566.0   15.974395        91.559454
# Churned (Repeat Use)        4829.0  15423.0  367.022986       380.628392
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta    Maturity  \
# New                         9115518.0       0.003708     1.623437    0.000000
# Churned (Single Use Only)  18337961.0       0.031062     0.537534    0.000000
# Recent & Loyals             3634735.0      17.178592   -59.957829   27.259082
# Champions                   5135936.0      78.906297   -32.148687  341.836415
# Churned (Repeat Use)       21350969.0      71.539049   -28.210470  219.660592
#
#                            Frequency          AOV
# New                         1.000000   592.994926
# Churned (Single Use Only)   1.000000  1079.338493
# Recent & Loyals             2.267208   766.336707
# Champions                   5.072546  1440.251262
# Churned (Repeat Use)        3.193829  1384.359009
#                              Users   Orders     Recency  AOVContribution  \
# New                        15707.0  15707.0   95.300821       155.576618
# Churned (Single Use Only)  17311.0  17311.0  542.546300       328.215788
# Recent & Loyals             2139.0   4861.0   85.697990        61.757688
# Champions                    759.0   3736.0   17.562582        91.795412
# Churned (Repeat Use)        4895.0  15617.0  370.379775       377.800933
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta    Maturity  \
# New                         8903961.0       0.001369     0.961820    0.000000
# Churned (Single Use Only)  18784446.0       0.030486     1.005105    0.000000
# Recent & Loyals             3534516.0      17.237180   -58.053077   26.833567
# Champions                   5253635.0      79.086800   -29.452895  330.032938
# Churned (Repeat Use)       21622303.0      71.351269   -28.664878  218.636364
#
#                            Frequency          AOV
# New                         1.000000   566.878525
# Churned (Single Use Only)   1.000000  1085.116169
# Recent & Loyals             2.272557   727.117054
# Champions                   4.922266  1406.219218
# Churned (Repeat Use)        3.190398  1384.536275
#                              Users   Orders     Recency  AOVContribution  \
# New                        15976.0  15976.0   95.479407       149.793551
# Churned (Single Use Only)  17602.0  17602.0  544.520736       328.360109
# Recent & Loyals             2189.0   4969.0   85.005939        59.241183
# Champions                    801.0   3861.0   20.579276        92.379176
# Churned (Repeat Use)        4958.0  15805.0  374.078862       376.135502
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta    Maturity  \
# New                         8719932.0       0.001346     0.390950    0.000000
# Churned (Single Use Only)  19114827.0       0.029982     1.470233    0.000000
# Recent & Loyals             3448607.0      16.999279   -56.805668   25.820923
# Champions                   5377669.0      80.658391   -26.517679  329.529338
# Churned (Repeat Use)       21895976.0      71.076205   -27.797157  217.094796
#
#                            Frequency          AOV
# New                         1.000000   545.814472
# Churned (Single Use Only)   1.000000  1085.946313
# Recent & Loyals             2.269986   694.024351
# Champions                   4.820225  1392.817664
# Churned (Repeat Use)        3.187777  1385.382854
#                              Users   Orders     Recency  AOVContribution  \
# New                        16291.0  16291.0   94.115156       144.038110
# Churned (Single Use Only)  17981.0  17981.0  545.067238       328.012238
# Recent & Loyals             2252.0   5108.0   84.729574        57.739122
# Champions                    699.0   3279.0   17.731044        76.087885
# Churned (Repeat Use)        5164.0  16748.0  367.199264       390.391839
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta    Maturity  \
# New                         8556872.0       0.001320    -0.652857    0.000000
# Churned (Single Use Only)  19486223.0       0.029350     2.541046    0.000000
# Recent & Loyals             3430108.0      17.032827   -55.194503   25.438277
# Champions                   4520153.0      82.989356   -19.522846  313.635193
# Churned (Repeat Use)       23192008.0      71.313966   -28.152675  222.098954
#
#                            Frequency          AOV
# New                         1.000000   525.251489
# Churned (Single Use Only)   1.000000  1083.711863
# Recent & Loyals             2.268206   671.516836
# Champions                   4.690987  1378.515706
# Churned (Repeat Use)        3.243222  1384.762837
#                              Users   Orders     Recency  AOVContribution  \
# New                        16521.0  16521.0   95.377520       140.159570
# Churned (Single Use Only)  18240.0  18240.0  547.667982       327.148097
# Recent & Loyals             2305.0   5239.0   85.117137        56.318593
# Champions                    637.0   3042.0   16.929356        69.367472
# Churned (Repeat Use)        5317.0  17270.0  364.969908       395.460655
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta    Maturity  \
# New                         8453304.0       0.001301    -1.220589    0.000000
# Churned (Single Use Only)  19730956.0       0.028934     3.011543    0.000000
# Recent & Loyals             3396687.0      17.014494   -48.336828   25.121909
# Champions                   4183691.0      81.378721   -22.725448  314.211931
# Churned (Repeat Use)       23851023.0      71.636007   -31.244888  222.826218
#
#                            Frequency          AOV
# New                         1.000000   511.670238
# Churned (Single Use Only)   1.000000  1081.741009
# Recent & Loyals             2.272885   648.346440
# Champions                   4.775510  1375.309336
# Churned (Repeat Use)        3.248072  1381.066763
#                              Users   Orders     Recency  AOVContribution  \
# New                        16875.0  16875.0   95.811200       135.519389
# Churned (Single Use Only)  18521.0  18521.0  549.849900       327.140234
# Recent & Loyals             2343.0   5336.0   84.608195        54.038044
# Champions                    642.0   3111.0   17.590343        68.365452
# Churned (Repeat Use)        5420.0  17533.0  366.644280       394.791221
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta    Maturity  \
# New                         8317638.0       0.002696    -1.667285    0.000000
# Churned (Single Use Only)  20078559.0       0.028495     3.324979    0.000000
# Recent & Loyals             3316639.0      16.861430   -41.227962   24.679898
# Champions                   4195998.0      84.859904    -7.885983  316.760125
# Churned (Repeat Use)       24230706.0      71.327180   -34.981276  221.562177
#
#                            Frequency          AOV
# New                         1.000000   492.897067
# Churned (Single Use Only)   1.000000  1084.096917
# Recent & Loyals             2.277422   621.559033
# Champions                   4.845794  1348.761813
# Churned (Repeat Use)        3.234871  1382.005704
#                              Users   Orders     Recency  AOVContribution  \
# New                        17073.0  17073.0   99.293622       131.897177
# Churned (Single Use Only)  18661.0  18661.0  554.436204       326.764723
# Recent & Loyals             2381.0   5425.0   86.146997        52.048022
# Champions                    607.0   3137.0   17.607908        68.658051
# Churned (Repeat Use)        5542.0  17801.0  366.742331       394.939240
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta    Maturity  \
# New                         8190419.0       0.003075    -1.727362    0.000000
# Churned (Single Use Only)  20291109.0       0.028281     3.330892    0.000000
# Recent & Loyals             3232026.0      16.742498   -40.340700   23.975640
# Champions                   4263459.0      83.447538   -11.406582  331.828666
# Churned (Repeat Use)       24524542.0      71.376501   -33.774243  219.948575
#
#                            Frequency          AOV
# New                         1.000000   479.729339
# Churned (Single Use Only)   1.000000  1087.353786
# Recent & Loyals             2.278454   595.765161
# Champions                   5.168040  1359.087982
# Churned (Repeat Use)        3.212017  1377.705859
#                              Users   Orders     Recency  AOVContribution  \
# New                        17084.0  17084.0  103.718157       131.213049
# Churned (Single Use Only)  18684.0  18684.0  558.982712       326.468596
# Recent & Loyals             2401.0   5480.0   89.380258        51.759786
# Champions                    567.0   2992.0   18.649030        66.190284
# Churned (Repeat Use)        5608.0  18046.0  367.702924       397.796535
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta    Maturity  \
# New                         8172736.0       0.003073    -1.877288    0.000000
# Churned (Single Use Only)  20334423.0       0.028246     3.324374    0.000000
# Recent & Loyals             3223910.0      16.740298   -39.105320   23.949188
# Champions                   4122728.0      84.882993   -17.645088  339.613757
# Churned (Repeat Use)       24777155.0      71.464296   -33.342443  220.314907
#
#                            Frequency          AOV
# New                         1.000000   478.385390
# Churned (Single Use Only)   1.000000  1088.333494
# Recent & Loyals             2.282382   588.304745
# Champions                   5.276896  1377.917112
# Churned (Repeat Use)        3.217903  1372.999834

# %%
usersegstats
# Out:
#                              Users   Orders     Recency  AOVContribution  \
# New                        17084.0  17084.0  103.718157       131.213049
# Churned (Single Use Only)  18684.0  18684.0  558.982712       326.468596
# Recent & Loyals             2401.0   5480.0   89.380258        51.759786
# Champions                    567.0   2992.0   18.649030        66.190284
# Churned (Repeat Use)        5608.0  18046.0  367.702924       397.796535
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta    Maturity  \
# New                         8172736.0       0.003073    -1.877288    0.000000
# Churned (Single Use Only)  20334423.0       0.028246     3.324374    0.000000
# Recent & Loyals             3223910.0      16.740298   -39.105320   23.949188
# Champions                   4122728.0      84.882993   -17.645088  339.613757
# Churned (Repeat Use)       24777155.0      71.464296   -33.342443  220.314907
#
#                            Frequency          AOV
# New                         1.000000   478.385390
# Churned (Single Use Only)   1.000000  1088.333494
# Recent & Loyals             2.282382   588.304745
# Champions                   5.276896  1377.917112
# Churned (Repeat Use)        3.217903  1372.999834

# %%
userweeklydata[userweeklydata['CohortLabel']=='Recent & Loyals']
# Out:
#             user_id  Last_Date First_Date  OrdersCount  Frequency  \
# 1895   3.660581e+12 2023-06-28 2023-06-28            2          2
# 2438   3.685691e+12 2023-07-07 2023-07-07            2          2
# 3358   5.057566e+12 2023-09-11 2023-07-26            3          3
# 3369   5.058281e+12 2023-07-29 2023-06-20            2          2
# 4471   5.149082e+12 2023-07-28 2023-06-24            2          2
# ...             ...        ...        ...          ...        ...
# 44162  6.955885e+12 2023-12-15 2023-12-15            3          3
# 44193  6.956044e+12 2023-12-15 2023-12-15            2          2
# 44246  6.958520e+12 2023-12-18 2023-12-16            2          2
# 44247  6.958529e+12 2023-12-16 2023-12-16            2          2
# 44316  6.963087e+12 2023-12-19 2023-12-19            2          2
#
#        Order_Value  Mean_Days_Delta  Mean_OV_Delta  Recency Activated_Quater  \
# 1895        3490.0         0.000000     133.333333      176           2023Q2
# 2438        2297.0         0.000000      33.333333      167           2023Q3
# 3358        3695.0         9.400000     -16.000000      101           2023Q3
# 3369        2470.0        39.000000    -130.000000      145           2023Q2
# 4471        5139.0        11.333333    -103.333333      146           2023Q2
# ...            ...              ...            ...      ...              ...
# 44162        797.0         0.000000      50.000000        6           2023Q4
# 44193       1730.0         0.000000    -470.000000        6           2023Q4
# 44246        498.0         2.000000    -100.000000        3           2023Q4
# 44247        498.0         0.000000     100.000000        5           2023Q4
# 44316        598.0         0.000000       0.000000        2           2023Q4
#
#        MaturityAge  Customer_AOV  f_score  r_score  AOV_score  m_score  \
# 1895           0.0   1745.000000        4        3          4        1
# 2438           0.0   1148.500000        4        3          3        1
# 3358          47.0   1231.666667        4        3          4        2
# 3369          39.0   1235.000000        4        3          4        2
# 4471          34.0   2569.500000        4        3          4        2
# ...            ...           ...      ...      ...        ...      ...
# 44162          0.0    265.666667        4        4          1        1
# 44193          0.0    865.000000        4        4          3        1
# 44246          2.0    249.000000        4        4          1        1
# 44247          0.0    249.000000        4        4          1        1
# 44316          0.0    299.000000        4        4          2        1
#
#        DelAOV  SumScore      CohortLabel
# 1895        4        16  Recent & Loyals
# 2438        4        15  Recent & Loyals
# 3358        1        14  Recent & Loyals
# 3369        1        14  Recent & Loyals
# 4471        1        14  Recent & Loyals
# ...       ...       ...              ...
# 44162       4        14  Recent & Loyals
# 44193       1        13  Recent & Loyals
# 44246       1        11  Recent & Loyals
# 44247       4        14  Recent & Loyals
# 44316       4        15  Recent & Loyals
#
# [2401 rows x 19 columns]

# %%
weeklyusersegsats['23-w35']
# Out:
#                              Users   Orders     Recency  AOVContribution  \
# New                        12910.0  12910.0  105.099380       221.710354
# Churned (Single Use Only)  14240.0  14240.0  528.525492       326.142203
# Recent & Loyals             1696.0   3874.0  108.287736        92.770409
# Champions                    430.0   2257.0   21.144186        72.031274
# Churned (Repeat Use)        4200.0  13659.0  342.276190       404.428441
#
#                            OrderValue  MeanDaysDelta  MeanOVDelta    Maturity  \
# New                        10407084.0       0.002014     1.651219    0.000000
# Churned (Single Use Only)  15309115.0       0.036078     1.455018    0.000000
# Recent & Loyals             4354643.0      16.965746   -41.345708   33.931604
# Champions                   3381148.0      72.268406   -13.544361  357.581395
# Churned (Repeat Use)       18983871.0      75.099967   -28.852186  227.641667
#
#                            Frequency          AOV
# New                         1.000000   806.125794
# Churned (Single Use Only)   1.000000  1075.078301
# Recent & Loyals             2.284198  1124.068921
# Champions                   5.248837  1498.071777
# Churned (Repeat Use)        3.252143  1389.843400

# %%
each_metric_df = {}
ListofCustomerCohortVariables = usersegstats.columns.to_list()
Line_Chart_Variable_List_Customer = ['Recency', 'OrderValue', 'MeanDaysDelta', 'MeanOVDelta', 'Maturity', 'Frequency', 'AOV']
Stack_Chart_Variable_List_Customer = ['Users', 'Orders', 'AOVContribution']
user_cohort_labels = ['Champions', 'Churned (Repeat Use)', 'Churned (Single Use Only)', 'New', 'Recent & Loyals']
for week, df in weeklyusersegsats.items():
    df.sort_index(inplace=True)


def metric_graph(metric):
    if metric in Line_Chart_Variable_List_Customer:
        column_df = pd.DataFrame({week: df[metric].tolist() for week, df in weeklyusersegsats.items()})
        column_df.index = user_cohort_labels
        column_transposed = column_df.transpose()
        insights_table = column_transposed
        # print(Line_Chart_Table)
        each_metric_df[metric] = column_transposed
        weeks = column_transposed.index.to_list()

        for column_name, values in column_transposed.items():
            # Skip plotting if any value in the column is zero
            if not all(value == 0 for value in values):
                plt.plot(weeks, values, label=column_name)

        plt.xlabel('Weeks')
        plt.ylabel(metric)
        plt.title(f'{metric}')
        plt.xticks(fontsize=4, rotation=90)
        plt.legend(loc='upper left', bbox_to_anchor=(1, 1), title='Customer Cohort Labels')
        plt.show()

    if metric in Stack_Chart_Variable_List_Customer:
      variable_df = pd.DataFrame({week: df[metric].tolist() for week, df in weeklyusersegsats.items()})
      variable_df.index = user_cohort_labels
      variable_df_transposed = variable_df.transpose()
      each_metric_df[metric] = variable_df_transposed
      insights_table = variable_df_transposed
      # print(Stack_Chart_Table)
      variable_df_transposed.plot(kind='bar', stacked=True, figsize=(8, 4))
      plt.title(f'{metric}')
      plt.xticks(fontsize=4)
      plt.xlabel('Weeks')
      plt.ylabel(metric)
      plt.legend(loc='upper left', bbox_to_anchor=(1,1), title = 'Customer Cohort Lables')
      plt.show()
    return insights_table

# result = metric_graph('Recency')
# result_1 = metric_graph('MeanDaysDelta')
# result_2 = metric_graph('OrderValue')
# result_3 = metric_graph('MeanOVDelta')
# result_4 = metric_graph('Maturity')
# result_5 = metric_graph('Frequency')
# result_6 = metric_graph('AOV')
result_7 = metric_graph('Users')
# result_8 = metric_graph('Orders')
# result_9 = metric_graph('AOVContribution')

# %%
# file_path = 'output.xlsx'

# with pd.ExcelWriter(file_path) as writer:
#     startrow = 0
#     for dataframe in [result, result_1, result_2, result_3, result_4, result_5, result_6, result_7, result_8, result_9]:
#         dataframe.to_excel(writer, sheet_name='Sheet1', startrow=startrow, startcol=0, index=False)
#         startrow += dataframe.shape[0] + 1

# %%
result
# Out:
#         Champions  Churned (Repeat Use)  Churned (Single Use Only)  \
# 20-w38   1.750000              2.000000                   2.658537
# 20-w39   4.416667              9.000000                   9.576000
# 20-w40  11.416667             16.000000                  16.552430
# 20-w41  16.702703             23.000000                  23.526829
# 20-w42  21.044444             30.000000                  30.442765
# ...           ...                   ...                        ...
# 23-w47  17.731044            367.199264                 545.067238
# 23-w48  16.929356            364.969908                 547.667982
# 23-w49  17.590343            366.644280                 549.849900
# 23-w50  17.607908            366.742331                 554.436204
# 23-w51  18.649030            367.702924                 558.982712
#
#                New  Recent & Loyals
# 20-w38    1.486928         1.500000
# 20-w39    6.773994         7.230769
# 20-w40   12.648968        14.230769
# 20-w41   17.641243        19.137931
# 20-w42   18.070000        21.250000
# ...            ...              ...
# 23-w47   94.115156        84.729574
# 23-w48   95.377520        85.117137
# 23-w49   95.811200        84.608195
# 23-w50   99.293622        86.146997
# 23-w51  103.718157        89.380258
#
# [172 rows x 5 columns]

# %%
result_1
# Out:
#         Champions  Churned (Repeat Use)  Churned (Single Use Only)       New  \
# 20-w38   1.171627              0.000000                   0.000000  0.000000
# 20-w39   4.359788              0.000000                   0.000000  0.000000
# 20-w40   4.359788              0.000000                   0.000000  0.000000
# 20-w41   4.862613              0.000000                   0.000000  0.000000
# 20-w42   7.322658              0.000000                   0.000000  0.000000
# ...           ...                   ...                        ...       ...
# 23-w47  82.989356             71.313966                   0.029350  0.001320
# 23-w48  81.378721             71.636007                   0.028934  0.001301
# 23-w49  84.859904             71.327180                   0.028495  0.002696
# 23-w50  83.447538             71.376501                   0.028281  0.003075
# 23-w51  84.882993             71.464296                   0.028246  0.003073
#
#         Recent & Loyals
# 20-w38         0.000000
# 20-w39         1.413462
# 20-w40         1.413462
# 20-w41         1.353448
# 20-w42         1.132812
# ...                 ...
# 23-w47        17.032827
# 23-w48        17.014494
# 23-w49        16.861430
# 23-w50        16.742498
# 23-w51        16.740298
#
# [172 rows x 5 columns]

# %%
result_2
# Out:
#         Champions  Churned (Repeat Use)  Churned (Single Use Only)        New  \
# 20-w38    49194.0                6500.0                   212950.0   198835.0
# 20-w39    99559.0               14300.0                   243500.0   296732.0
# 20-w40    99559.0               14300.0                   253900.0   334197.0
# 20-w41   104658.0               15600.0                   266250.0   351284.0
# 20-w42   125680.0               16900.0                   300635.0   394680.0
# ...           ...                   ...                        ...        ...
# 23-w47  4520153.0            23192008.0                 19486223.0  8556872.0
# 23-w48  4183691.0            23851023.0                 19730956.0  8453304.0
# 23-w49  4195998.0            24230706.0                 20078559.0  8317638.0
# 23-w50  4263459.0            24524542.0                 20291109.0  8190419.0
# 23-w51  4122728.0            24777155.0                 20334423.0  8172736.0
#
#         Recent & Loyals
# 20-w38          16250.0
# 20-w39          47244.0
# 20-w40          47244.0
# 20-w41          55990.0
# 20-w42          67583.0
# ...                 ...
# 23-w47        3430108.0
# 23-w48        3396687.0
# 23-w49        3316639.0
# 23-w50        3232026.0
# 23-w51        3223910.0
#
# [172 rows x 5 columns]

# %%
result_3
# Out:
#          Champions  Churned (Repeat Use)  Churned (Single Use Only)       New  \
# 20-w38    6.244048              0.000000                   0.000000  0.000000
# 20-w39 -894.286376              0.000000                   0.000000  0.000000
# 20-w40 -894.286376              0.000000                   0.000000 -3.020649
# 20-w41 -874.970721              0.000000                   0.000000 -2.892655
# 20-w42 -737.617429              0.000000                   0.000000 -2.360000
# ...            ...                   ...                        ...       ...
# 23-w47  -19.522846            -28.152675                   2.541046 -0.652857
# 23-w48  -22.725448            -31.244888                   3.011543 -1.220589
# 23-w49   -7.885983            -34.981276                   3.324979 -1.667285
# 23-w50  -11.406582            -33.774243                   3.330892 -1.727362
# 23-w51  -17.645088            -33.342443                   3.324374 -1.877288
#
#         Recent & Loyals
# 20-w38         0.000000
# 20-w39      -171.471154
# 20-w40      -171.471154
# 20-w41      -135.646552
# 20-w42       -60.492188
# ...                 ...
# 23-w47       -55.194503
# 23-w48       -48.336828
# 23-w49       -41.227962
# 23-w50       -40.340700
# 23-w51       -39.105320
#
# [172 rows x 5 columns]

# %%
result_4
# Out:
#          Champions  Churned (Repeat Use)  Churned (Single Use Only)  New  \
# 20-w38    1.291667              0.000000                        0.0  0.0
# 20-w39    5.055556              0.000000                        0.0  0.0
# 20-w40    5.055556              0.000000                        0.0  0.0
# 20-w41    6.243243              0.000000                        0.0  0.0
# 20-w42    8.622222              0.000000                        0.0  0.0
# ...            ...                   ...                        ...  ...
# 23-w47  313.635193            222.098954                        0.0  0.0
# 23-w48  314.211931            222.826218                        0.0  0.0
# 23-w49  316.760125            221.562177                        0.0  0.0
# 23-w50  331.828666            219.948575                        0.0  0.0
# 23-w51  339.613757            220.314907                        0.0  0.0
#
#         Recent & Loyals
# 20-w38         0.000000
# 20-w39         1.769231
# 20-w40         1.769231
# 20-w41         1.758621
# 20-w42         1.531250
# ...                 ...
# 23-w47        25.438277
# 23-w48        25.121909
# 23-w49        24.679898
# 23-w50        23.975640
# 23-w51        23.949188
#
# [172 rows x 5 columns]

# %%
result_5
# Out:
#         Champions  Churned (Repeat Use)  Churned (Single Use Only)  New  \
# 20-w38   2.750000              2.500000                        1.0  1.0
# 20-w39   2.416667              2.750000                        1.0  1.0
# 20-w40   2.416667              2.750000                        1.0  1.0
# 20-w41   2.513514              2.666667                        1.0  1.0
# 20-w42   2.533333              2.600000                        1.0  1.0
# ...           ...                   ...                        ...  ...
# 23-w47   4.690987              3.243222                        1.0  1.0
# 23-w48   4.775510              3.248072                        1.0  1.0
# 23-w49   4.845794              3.234871                        1.0  1.0
# 23-w50   5.168040              3.212017                        1.0  1.0
# 23-w51   5.276896              3.217903                        1.0  1.0
#
#         Recent & Loyals
# 20-w38         2.083333
# 20-w39         2.423077
# 20-w40         2.423077
# 20-w41         2.413793
# 20-w42         2.406250
# ...                 ...
# 23-w47         2.268206
# 23-w48         2.272885
# 23-w49         2.277422
# 23-w50         2.278454
# 23-w51         2.282382
#
# [172 rows x 5 columns]

# %%
result_6
# Out:
#           Champions  Churned (Repeat Use)  Churned (Single Use Only)  \
# 20-w38   745.363636            650.000000                 649.237805
# 20-w39  1144.356322            650.000000                 649.333333
# 20-w40  1144.356322            650.000000                 649.360614
# 20-w41  1125.354839            650.000000                 649.390244
# 20-w42  1102.456140            650.000000                 649.319654
# ...             ...                   ...                        ...
# 23-w47  1378.515706           1384.762837                1083.711863
# 23-w48  1375.309336           1381.066763                1081.741009
# 23-w49  1348.761813           1382.005704                1084.096917
# 23-w50  1359.087982           1377.705859                1087.353786
# 23-w51  1377.917112           1372.999834                1088.333494
#
#                New  Recent & Loyals
# 20-w38  649.787582       650.000000
# 20-w39  918.674923       749.904762
# 20-w40  985.831858       749.904762
# 20-w41  992.327684       799.857143
# 20-w42  986.700000       877.701299
# ...            ...              ...
# 23-w47  525.251489       671.516836
# 23-w48  511.670238       648.346440
# 23-w49  492.897067       621.559033
# 23-w50  479.729339       595.765161
# 23-w51  478.385390       588.304745
#
# [172 rows x 5 columns]

# %%
result_7
# Out:
#         Champions  Churned (Repeat Use)  Churned (Single Use Only)      New  \
# 20-w38       24.0                   4.0                      328.0    306.0
# 20-w39       36.0                   8.0                      375.0    323.0
# 20-w40       36.0                   8.0                      391.0    339.0
# 20-w41       37.0                   9.0                      410.0    354.0
# 20-w42       45.0                  10.0                      463.0    400.0
# ...           ...                   ...                        ...      ...
# 23-w47      699.0                5164.0                    17981.0  16291.0
# 23-w48      637.0                5317.0                    18240.0  16521.0
# 23-w49      642.0                5420.0                    18521.0  16875.0
# 23-w50      607.0                5542.0                    18661.0  17073.0
# 23-w51      567.0                5608.0                    18684.0  17084.0
#
#         Recent & Loyals
# 20-w38             12.0
# 20-w39             26.0
# 20-w40             26.0
# 20-w41             29.0
# 20-w42             32.0
# ...                 ...
# 23-w47           2252.0
# 23-w48           2305.0
# 23-w49           2343.0
# 23-w50           2381.0
# 23-w51           2401.0
#
# [172 rows x 5 columns]

# %%
result_8
# Out:
#         Champions  Churned (Repeat Use)  Churned (Single Use Only)      New  \
# 20-w38       66.0                  10.0                      328.0    306.0
# 20-w39       87.0                  22.0                      375.0    323.0
# 20-w40       87.0                  22.0                      391.0    339.0
# 20-w41       93.0                  24.0                      410.0    354.0
# 20-w42      114.0                  26.0                      463.0    400.0
# ...           ...                   ...                        ...      ...
# 23-w47     3279.0               16748.0                    17981.0  16291.0
# 23-w48     3042.0               17270.0                    18240.0  16521.0
# 23-w49     3111.0               17533.0                    18521.0  16875.0
# 23-w50     3137.0               17801.0                    18661.0  17073.0
# 23-w51     2992.0               18046.0                    18684.0  17084.0
#
#         Recent & Loyals
# 20-w38             25.0
# 20-w39             63.0
# 20-w40             63.0
# 20-w41             70.0
# 20-w42             77.0
# ...                 ...
# 23-w47           5108.0
# 23-w48           5239.0
# 23-w49           5336.0
# 23-w50           5425.0
# 23-w51           5480.0
#
# [172 rows x 5 columns]

# %%
result_9
# Out:
#          Champions  Churned (Repeat Use)  Churned (Single Use Only)  \
# 20-w38   66.930612              8.843537                 289.727891
# 20-w39  114.435632             16.436782                 279.885057
# 20-w40  110.375831             15.853659                 281.485588
# 20-w41  110.050473             16.403785                 279.968454
# 20-w42  116.370370             15.648148                 278.365741
# ...            ...                   ...                        ...
# 23-w47   76.087885            390.391839                 328.012238
# 23-w48   69.367472            395.460655                 327.148097
# 23-w49   68.365452            394.791221                 327.140234
# 23-w50   68.658051            394.939240                 326.764723
# 23-w51   66.190284            397.796535                 326.468596
#
#                New  Recent & Loyals
# 20-w38  270.523810        22.108844
# 20-w39  341.071264        54.303448
# 20-w40  370.506652        52.376940
# 20-w41  369.383807        58.874869
# 20-w42  365.444444        62.576852
# ...            ...              ...
# 23-w47  144.038110        57.739122
# 23-w48  140.159570        56.318593
# 23-w49  135.519389        54.038044
# 23-w50  131.897177        52.048022
# 23-w51  131.213049        51.759786
#
# [172 rows x 5 columns]

# %%
def metric_cohort_graph(metric, cohort):
    if metric in Line_Chart_Variable_List_Customer:
        column_df = pd.DataFrame({week: df[metric].tolist() for week, df in weeklyusersegsats.items()})
        column_df.index = user_cohort_labels
        column_transposed = column_df.transpose()
        each_metric_df[metric] = column_transposed[cohort]  # Select only the specified cohort column

        # Replace zero values with np.nan
        each_metric_df[metric] = np.where(each_metric_df[metric] == 0, np.nan, each_metric_df[metric])

        plt.plot(column_transposed.index, each_metric_df[metric], label=cohort)
        plt.xlabel('Weeks')
        plt.ylabel(metric)
        plt.title(f'Weekly {metric}')
        plt.xticks(fontsize=4, rotation=90)
        plt.legend(loc='upper left', bbox_to_anchor=(1, 1), title='Customer Cohort Labels')
        plt.show()

    if metric in Stack_Chart_Variable_List_Customer:
        variable_df = pd.DataFrame({week: df[metric].tolist() for week, df in weeklyusersegsats.items()})
        variable_df.index = user_cohort_labels
        variable_df_transposed = variable_df.transpose()
        each_metric_df[metric] = variable_df_transposed[cohort]  # Select only the specified cohort column

        # Replace zero values with np.nan
        each_metric_df[metric] = np.where(each_metric_df[metric] == 0, np.nan, each_metric_df[metric])

        graph2 = pd.DataFrame({cohort: each_metric_df[metric]})
        graph2.plot(kind='bar', stacked=True, figsize=(8, 4))
        plt.title(f'Weekly {metric}')
        plt.xticks(fontsize=4)
        plt.xlabel('Weeks')
        plt.ylabel(metric)
        plt.legend(loc='upper left', bbox_to_anchor=(1, 1), title='Customer Cohort Labels')
        plt.show()

# Call the function with the specified metric and cohort
output = metric_cohort_graph('Users', 'New')
