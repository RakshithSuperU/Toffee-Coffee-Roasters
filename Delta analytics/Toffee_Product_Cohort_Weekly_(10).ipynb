# %%
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import pandas as pd
import psycopg2
import calendar
import random
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
conn = psycopg2.connect(
host = "shopify-merchant-dump.ccm9mnr5avgs.ap-south-1.rds.amazonaws.com",
  user = "toffee_coffee_roasters_69e3f806d0674953afe3d3fb2f724c7c",
  password = "toffee_coffee_roasters_69e3f806d0674953afe3d3fb2f724c7c_password",
  database = "toffee_coffee_roasters_69e3f806d0674953afe3d3fb2f724c7c_db",
  port = '5432'
)

# %%
# query1 = """select o.id as order_id,
#             o.created_at::date as order_date,
#             o.customer_id as user_id,
#             oli.product_id as product_id,
#             oli.name as product_name,
#             CASE
#         WHEN cancelled_at IS NOT NULL THEN 'Cancelled'
#          ELSE 'Delivered'
#      END as order_status,
#             oli.quantity as quantity,
#             oli.price as sp
#             from orders o
#             join order_line_item oli on oli.order_id = o.id"""

query1='''
    select o.id as order_id,
    o.created_at::date as order_date,
    o.email as user_id,
    o.total_line_items_price as MRP,
    o.total_discounts as discount_amount,
    total_price as total_price

    from orders o
    WHERE
    cancelled_at is NULL;
'''

query2='''
    select oli.order_id as order_id,
    oli.product_id as product_id,
    oli.name as product_name,
    oli.quantity as quantity,
    oli.price as sp
    from order_line_item oli;
'''

# %%
o=pd.read_sql(query1,conn)

# %%
r=pd.read_sql(query2,conn)

# %%
# data = pd.read_sql(query1, conn)
data=pd.merge(o,r,on='order_id',how='left')
data['order_id'].nunique()
# Out:
# 72899

# %%
data["order_date"] = pd.to_datetime(data["order_date"])

# %%
data[data["product_id"] == np.nan]
# Out:
# Empty DataFrame
# Columns: [order_id, order_date, user_id, mrp, discount_amount, total_price, product_id, product_name, quantity, sp]
# Index: []

# %%
data['WeekCount']=data['order_date'].dt.strftime('%y-w%U')

# %%
data = data.dropna()

# %%
data=data.sort_values('order_date')
WeekList=data['WeekCount'].unique()

# %%
len(data)
# Out:
# 95149

# %%
WeekList.tolist()
output_list = []

for i in range(len(WeekList) - 1):
    output_list.append(WeekList[i])
    current_week = int(WeekList[i].split('-w')[1])
    next_week = int(WeekList[i + 1].split('-w')[1])
    missing_weeks = next_week - current_week - 1
    for j in range(1, missing_weeks + 1):
        missing_week = current_week + j
        output_list.append(f'{WeekList[i][:3]}w{missing_week:02d}')

output_list.append(WeekList[-1])

# %%
# output_list=output_list[-52:]
# output_list

# %%
#New/Repeat Tag
orderuserlevel=data.groupby(['order_id','user_id']).agg(
          order_date=pd.NamedAgg(column='order_date', aggfunc='min'),

    ).reset_index()
orderuserlevel=orderuserlevel.sort_values('order_date')
orderuserlevel['TrxnRank'] = orderuserlevel.groupby('user_id')['order_date'].rank(method='first')
orderuserlevel



# data = data[data['order_date'] >= '2023-01-01']
# data=data[data['order_date'] <= '2023/12/31']

data=pd.merge(data,
         orderuserlevel[['order_id','TrxnRank']],
         on="order_id",
         how ='left')
data['New']=0
data['Repeat']=0
data.loc[data['TrxnRank']==1,'New']=1
data.loc[data['TrxnRank']>1,'Repeat']=1


#AOV Contribution
data['ordervalue']=data['quantity']*data['sp']
data['AOVContribution']=data['ordervalue']/data["order_id"].nunique()
data['discount_ratio'] = data['discount_amount']/data['mrp']
data['new_ordervalue']= data['ordervalue']-(data['ordervalue']*data['discount_ratio'])

# %%
data
# Out:
#             order_id order_date                       user_id     mrp  \
# 0      2418154733706 2020-09-12       devansh.bajaj@cred.club  1699.0
# 1      2418155159690 2020-09-12       devansh.bajaj@cred.club  1699.0
# 2      2418214437002 2020-09-12       devansh.bajaj@cred.club  1699.0
# 3      2418422546570 2020-09-12       devansh.bajaj@cred.club  1699.0
# 4      2418151194762 2020-09-12       devansh.bajaj@cred.club  1699.0
# ...              ...        ...                           ...     ...
# 95144  5381571641482 2024-01-06          rohit.seth@gmail.com  2480.0
# 95145  5381571641482 2024-01-06          rohit.seth@gmail.com  2480.0
# 95146  5381619482762 2024-01-06  mayank.mayankdayal@gmail.com  2500.0
# 95147  5381671354506 2024-01-06       meghasharda86@gmail.com  1100.0
# 95148  5381444894858 2024-01-06         mrudulamula@gmail.com   450.0
#
#        discount_amount  total_price    product_id  \
# 0               1698.0          1.0  5.321692e+12
# 1               1698.0          1.0  5.321692e+12
# 2               1698.0          1.0  5.321692e+12
# 3               1698.0          1.0  5.321692e+12
# 4               1698.0          1.0  5.321692e+12
# ...                ...          ...           ...
# 95144           1180.0       1300.0  5.379839e+12
# 95145           1180.0       1300.0  5.321622e+12
# 95146           1250.0       1250.0  6.747180e+12
# 95147            550.0        550.0  6.584809e+12
# 95148              0.0        450.0  5.405528e+12
#
#                                             product_name  quantity      sp  \
# 0      Cabernet Sauvignon - Wine Barrel Aged Coffee -...         1  1699.0
# 1      Cabernet Sauvignon - Wine Barrel Aged Coffee -...         1  1699.0
# 2      Cabernet Sauvignon - Wine Barrel Aged Coffee -...         1  1699.0
# 3      Cabernet Sauvignon - Wine Barrel Aged Coffee -...         1  1699.0
# 4      Cabernet Sauvignon - Wine Barrel Aged Coffee -...         1  1699.0
# ...                                                  ...       ...     ...
# 95144        Holiday Blend Coffee - Whole Beans / 250 gm         1   650.0
# 95145  Peaberry Coffee - Medium Roast - Whole Beans /...         1   630.0
# 95146  Hazelnut Cold Brew - Easy Brew Cold Brew Bags ...         2  1250.0
# 95147    Mullayangiri Estate Coffee - 250 gm / Pour Over         2   550.0
# 95148  Medium Dark Roast - Coffee Sample Pack - South...         1   450.0
#
#       WeekCount  TrxnRank  New  Repeat  ordervalue  AOVContribution  \
# 0        20-w36       3.0    0       1      1699.0         0.023338
# 1        20-w36       4.0    0       1      1699.0         0.023338
# 2        20-w36       5.0    0       1      1699.0         0.023338
# 3        20-w36       6.0    0       1      1699.0         0.023338
# 4        20-w36       2.0    0       1      1699.0         0.023338
# ...         ...       ...  ...     ...         ...              ...
# 95144    24-w00       5.0    0       1       650.0         0.008929
# 95145    24-w00       5.0    0       1       630.0         0.008654
# 95146    24-w00      12.0    0       1      2500.0         0.034341
# 95147    24-w00       2.0    0       1      1100.0         0.015110
# 95148    24-w00       3.0    0       1       450.0         0.006181
#
#        discount_ratio  new_ordervalue
# 0            0.999411        1.000000
# 1            0.999411        1.000000
# 2            0.999411        1.000000
# 3            0.999411        1.000000
# 4            0.999411        1.000000
# ...               ...             ...
# 95144        0.475806      340.725806
# 95145        0.475806      330.241935
# 95146        0.500000     1250.000000
# 95147        0.500000      550.000000
# 95148        0.000000      450.000000
#
# [95149 rows x 18 columns]

# %%
productsegstats_weekly = {}
for x in output_list:
    x3 = data[data["WeekCount"] <= x]
    try:
        totalcarts=x3['order_id'].nunique()
        product_level=x3.groupby(['product_id', 'product_name']).agg(
                Carts=pd.NamedAgg(column='order_id', aggfunc='nunique'),
                Quantity=pd.NamedAgg(column='quantity', aggfunc='sum'),
                ASP=pd.NamedAgg(column='sp', aggfunc='mean'),
                NewOrders=pd.NamedAgg(column='New', aggfunc='sum'),
                RepeatOrders=pd.NamedAgg(column='Repeat', aggfunc='sum'),
                Users=pd.NamedAgg(column='user_id', aggfunc='nunique'),
                AOVContribution=pd.NamedAgg(column='AOVContribution', aggfunc='sum'),
                Total_Order_Value=pd.NamedAgg(column='new_ordervalue', aggfunc='sum'),
                Order_Count=pd.NamedAgg(column='order_id', aggfunc='nunique')
        ).reset_index()
        data_new=x3[x3['TrxnRank']==1]
        xuser_count = data_new.groupby(["product_name"]).agg(
        x_trxn_pool = pd.NamedAgg(column = "user_id", aggfunc = 'nunique'),
        x_user_list = pd.NamedAgg(column = "user_id", aggfunc = lambda x: [x.unique()])
        ).reset_index()
        data_repeat=x3[x3['TrxnRank']==2]
        repeat_users=data_repeat['user_id'].to_list()
        l=[]
        for i in range (len(xuser_count)):
            a=(xuser_count.iloc[i,2])[0]
            b=[x for x in a if x in repeat_users]
            l.append(len(b))

        xuser_count['repeat_pool']=l

        yuser_count = data_repeat.groupby('product_name').agg(
        y_trxn_pool = pd.NamedAgg(column = "user_id", aggfunc = 'nunique')
        ).reset_index()
        main_grouped_for_title = pd.merge(xuser_count, yuser_count, on='product_name', how='left')
        main_grouped_for_title['y_trxn_pool'].fillna(0, inplace=True)
        result = main_grouped_for_title.copy()

        result['Conversion_Rate_x_to_y'] = result['repeat_pool']/result['x_trxn_pool']
        result['Conversion_Rate_x_to_y'].fillna(0, inplace= True)
        conversion_result = result
        productlevel=pd.merge(product_level,conversion_result,on='product_name', how='left')


        productlevel['NewRepeatConversionRatio']=productlevel['Conversion_Rate_x_to_y']
        productlevel['NewRepeatConversionRatio'].fillna(0)
        productlevel=productlevel.sort_values('NewRepeatConversionRatio')
        productlevel['CartPenetration']=productlevel['Carts']/totalcarts
        productlevel['QpC']=productlevel['Quantity']/productlevel['Carts']
        productlevel['ASPXQpC']=productlevel['ASP']*productlevel['QpC']

        CP_labels, NewRatio_labels,ASP_labels, QpC_labels =  range(1,5), range(1,5),range(1,5),range(1,5)
        productlevel['CP_score'] = productlevel['CartPenetration'].transform(lambda x: pd.qcut(x.rank(method='first'), q = [0, 0.25, 0.5, 0.75, 1], labels = CP_labels)).astype('int64')
        productlevel['NewRepeatConversion_score'] = productlevel['NewRepeatConversionRatio'].transform(lambda x: pd.qcut(x.rank(method='first'), q = [0, 0.25, 0.5, 0.75, 1], labels = NewRatio_labels))#.astype('int64')
        productlevel['ASP_score'] = productlevel['ASP'].transform(lambda x: pd.qcut(x.rank(method='first'), q = [0, 0.25, 0.5, 0.75, 1], labels = ASP_labels)).astype('int64')
        # productlevel['QpC_score'] = productlevel['QpC'].transform(lambda x: pd.qcut(x.rank(method='first'), q = [0, 0.25, 0.5, 0.75, 1], labels = QpC_labels)).astype('int64')
        # productlevel['SumScore'] = productlevel['CP_score'] + productlevel['NewRepeatConversion_score'] + productlevel['ASP_score'] + productlevel['QpC_score']
        def ProductCohortLables2(df):
            if ((df['CP_score']>2) and (df['NewRepeatConversion_score']>2)):
                return 'Hero Products'
            elif df['NewRepeatConversion_score'] >2:
                return 'High Repeat Products'
            elif (df['CP_score'] >2):
                return 'New Business Products'
            elif (df['ASP_score'] >3):
                return 'High Value & Slow Moving Products'
            elif (df['ASP_score'] <=3):
                return 'Low Value & Slow Moving Products'
            else:
                return 'Low Value & Slow Moving Products'
        productlevel['Product Cohort Lables'] = productlevel.apply(ProductCohortLables2, axis=1)
        p1=productlevel.groupby(
          'Product Cohort Lables'
        ).agg(
          ProductCount=pd.NamedAgg(column='product_name', aggfunc='nunique'),
          Orders=pd.NamedAgg(column='Carts', aggfunc='sum'),
          Total_Quantity=pd.NamedAgg(column='Quantity', aggfunc='sum'),
          Users=pd.NamedAgg(column='Users', aggfunc='sum'),
          AverageSellingPrice=pd.NamedAgg(column='ASP', aggfunc='mean'),
          QuantityperCart=pd.NamedAgg(column='QpC', aggfunc='mean'),
          CartPenetration  =pd.NamedAgg(column='CartPenetration', aggfunc='sum'),
          NewRepeatConversionRatio=pd.NamedAgg(column='NewRepeatConversionRatio', aggfunc='mean'),
          Total_Order_Value=pd.NamedAgg(column='Total_Order_Value', aggfunc='sum'),
          # OrderCount=pd.NamedAgg(column='Total_Order_Value', aggfunc='sum'),
          #  NewUserRatio=pd.NamedAgg(column='NewUserRatio', aggfunc='mean'),
          NewOrders=pd.NamedAgg(column='NewOrders', aggfunc='sum'),
          ASPXQpC=pd.NamedAgg(column='ASPXQpC', aggfunc='sum'),
          # AOVContribution=pd.NamedAgg(column='AOVContribution', aggfunc='sum'),
          Order_Count=pd.NamedAgg(column='Order_Count', aggfunc='sum'),
          Top10SKUs=pd.NamedAgg(column='product_name', aggfunc=lambda x: x.value_counts().index[:10]),
          Bottom10SKUs=pd.NamedAgg(column='product_name', aggfunc=lambda x: x.value_counts().index[-10:-1])

        ).reset_index()
        p1=p1.sort_values('CartPenetration', ascending =False)
        p1['AOVContribution']=p1['Total_Order_Value']/p1['Order_Count'].sum()
        p1
        p1['ProductCountMix']=p1['ProductCount']/p1['ProductCount'].sum()
        p1['OrdersMix']=p1['Orders']/p1['Orders'].sum()
        p1['UsersMix']=p1['Users']/p1['Users'].sum()
        p1['AOVContribution(%)']=p1['AOVContribution']/p1['AOVContribution'].sum()
        p1['OrderPerSKU']=p1['Orders']/p1['ProductCount']
        p1.set_index("Product Cohort Lables", inplace= True)
        product_cohort_labels = ['Hero Products', 'High Repeat Products', 'New Business Products', 'High Value & Slow Moving Products', 'Low Value & Slow Moving Products']
        cols = p1.columns.tolist()
        dummy_df = pd.DataFrame(index=product_cohort_labels, columns=cols)

        for i in product_cohort_labels:
            try:
                dummy_df.loc[i] = p1.loc[i]
            except KeyError:
                pass

        dummy_df = dummy_df.fillna(0)
        productsegstats_weekly[x] = dummy_df
    except:
        pass

# %%
productsegstats_weekly
# Out:
# {'20-w37':                                    ProductCount  Orders  Total_Quantity  \
#  Hero Products                                 2      21              21
#  High Repeat Products                          0       0               0
#  New Business Products                         1       2               2
#  High Value & Slow Moving Products             1       1               1
#  Low Value & Slow Moving Products              3       3               3
#
#                                     Users  AverageSellingPrice  \
#  Hero Products                         19          1174.500000
#  High Repeat Products                   0             0.000000
#  New Business Products                  1          1699.000000
#  High Value & Slow Moving Products      1          1699.000000
#  Low Value & Slow Moving Products       3           959.666667
#
#                                     QuantityperCart  CartPenetration  \
#  Hero Products                                  1.0         0.777778
#  High Repeat Products                           0.0         0.000000
#  New Business Products                          1.0         0.074074
#  High Value & Slow Moving Products              1.0         0.037037
#  Low Value & Slow Moving Products               1.0         0.111111
#
#                                     NewRepeatConversionRatio  \
#  Hero Products                                           0.5
#  High Repeat Products                                    0.0
#  New Business Products                                   0.0
#  High Value & Slow Moving Products                       0.0
#  Low Value & Slow Moving Products                        0.0
#
#                                     Total_Order_Value  NewOrders  ASPXQpC  \
#  Hero Products                                 7739.0         18   2349.0
#  High Repeat Products                             0.0          0      0.0
#  New Business Products                            2.0          0   1699.0
#  High Value & Slow Moving Products                1.0          0   1699.0
#  Low Value & Slow Moving Products              1181.0          2   2879.0
#
#                                     Order_Count  \
#  Hero Products                               21
#  High Repeat Products                         0
#  New Business Products                        2
#  High Value & Slow Moving Products            1
#  Low Value & Slow Moving Products             3
#
#                                                                             Top10SKUs  \
#  Hero Products                      [Easy Brew - Cold Brew Bags (Pack of 4), Caber...
#  High Repeat Products                                                               0
#  New Business Products              Cabernet Sauvignon - Wine Barrel Aged Coffee -...
#  High Value & Slow Moving Products  Cabernet Sauvignon - Wine Barrel Aged Coffee -...
#  Low Value & Slow Moving Products   [Mysore Nuggets - Speciality Blend - Espresso ...
#
#                                                                          Bottom10SKUs  \
#  Hero Products                                 Easy Brew - Cold Brew Bags (Pack of 4)
#  High Repeat Products                                                               0
#  New Business Products                                                             []
#  High Value & Slow Moving Products                                                 []
#  Low Value & Slow Moving Products   [Mysore Nuggets - Speciality Blend - Espresso ...
#
#                                     AOVContribution  ProductCountMix  \
#  Hero Products                           286.629630         0.285714
#  High Repeat Products                      0.000000         0.000000
#  New Business Products                     0.074074         0.142857
#  High Value & Slow Moving Products         0.037037         0.142857
#  Low Value & Slow Moving Products         43.740741         0.428571
#
#                                     OrdersMix  UsersMix  AOVContribution(%)  \
#  Hero Products                       0.777778  0.791667            0.867309
#  High Repeat Products                0.000000  0.000000            0.000000
#  New Business Products               0.074074  0.041667            0.000224
#  High Value & Slow Moving Products   0.037037  0.041667            0.000112
#  Low Value & Slow Moving Products    0.111111  0.125000            0.132355
#
#                                     OrderPerSKU
#  Hero Products                             10.5
#  High Repeat Products                       0.0
#  New Business Products                      2.0
#  High Value & Slow Moving Products          1.0
#  Low Value & Slow Moving Products           1.0  ,
#  '20-w38':                                    ProductCount  Orders  Total_Quantity  \
#  Hero Products                                 1       2               2
#  High Repeat Products                          1       1               1
#  New Business Products                         3     728             728
#  High Value & Slow Moving Products             1       1               1
#  Low Value & Slow Moving Products              3       3               3
#
#                                     Users  AverageSellingPrice  \
#  Hero Products                          1          1699.000000
#  High Repeat Products                   1           550.000000
#  New Business Products                672           978.000000
#  High Value & Slow Moving Products      1          1699.000000
#  Low Value & Slow Moving Products       3           971.333333
#
#                                     QuantityperCart  CartPenetration  \
#  Hero Products                                  1.0         0.002721
#  High Repeat Products                           1.0         0.001361
#  New Business Products                          1.0         0.990476
#  High Value & Slow Moving Products              1.0         0.001361
#  Low Value & Slow Moving Products               1.0         0.004082
#
#                                     NewRepeatConversionRatio  \
#  Hero Products                                      1.000000
#  High Repeat Products                               1.000000
#  New Business Products                              0.056801
#  High Value & Slow Moving Products                  0.000000
#  Low Value & Slow Moving Products                   0.000000
#
#                                     Total_Order_Value  NewOrders  ASPXQpC  \
#  Hero Products                                   2.00          1   1699.0
#  High Repeat Products                          550.00          1    550.0
#  New Business Products                      144089.85        669   2934.0
#  High Value & Slow Moving Products               1.00          0   1699.0
#  Low Value & Slow Moving Products             1216.00          1   2914.0
#
#                                     Order_Count  \
#  Hero Products                                2
#  High Repeat Products                         1
#  New Business Products                      728
#  High Value & Slow Moving Products            1
#  Low Value & Slow Moving Products             3
#
#                                                                             Top10SKUs  \
#  Hero Products                      Cabernet Sauvignon - Wine Barrel Aged Coffee -...
#  High Repeat Products               South Indian Traditional Filter Coffee - Mediu...
#  New Business Products              [Easy Brew - Cold Brew Bags (Pack of 4), Thogu...
#  High Value & Slow Moving Products  Cabernet Sauvignon - Wine Barrel Aged Coffee -...
#  Low Value & Slow Moving Products   [Mysore Nuggets - Speciality Blend - Espresso ...
#
#                                                                          Bottom10SKUs  \
#  Hero Products                                                                     []
#  High Repeat Products                                                              []
#  New Business Products              [Easy Brew - Cold Brew Bags (Pack of 4), Thogu...
#  High Value & Slow Moving Products                                                 []
#  Low Value & Slow Moving Products   [Mysore Nuggets - Speciality Blend - Espresso ...
#
#                                     AOVContribution  ProductCountMix  \
#  Hero Products                             0.002721         0.111111
#  High Repeat Products                      0.748299         0.111111
#  New Business Products                   196.040612         0.333333
#  High Value & Slow Moving Products         0.001361         0.111111
#  Low Value & Slow Moving Products          1.654422         0.333333
#
#                                     OrdersMix  UsersMix  AOVContribution(%)  \
#  Hero Products                       0.002721  0.001475            0.000014
#  High Repeat Products                0.001361  0.001475            0.003771
#  New Business Products               0.990476  0.991150            0.987872
#  High Value & Slow Moving Products   0.001361  0.001475            0.000007
#  Low Value & Slow Moving Products    0.004082  0.004425            0.008337
#
#                                     OrderPerSKU
#  Hero Products                         2.000000
#  High Repeat Products                  1.000000
#  New Business Products               242.666667
#  High Value & Slow Moving Products     1.000000
#  Low Value & Slow Moving Products      1.000000  ,
#  '20-w39':                                    ProductCount  Orders  Total_Quantity  \
#  Hero Products                                 3     777             777
#  High Repeat Products                          1       2               2
#  New Business Products                         3      85              85
#  High Value & Slow Moving Products             0       0               0
#  Low Value & Slow Moving Products              5       6               6
#
#                                     Users  AverageSellingPrice  \
#  Hero Products                        722          1349.333333
#  High Repeat Products                   1           550.000000
#  New Business Products                 84          1699.000000
#  High Value & Slow Moving Products      0             0.000000
#  Low Value & Slow Moving Products       5           596.000000
#
#                                     QuantityperCart  CartPenetration  \
#  Hero Products                                  1.0         0.893103
#  High Repeat Products                           1.0         0.002299
#  New Business Products                          1.0         0.097701
#  High Value & Slow Moving Products              0.0         0.000000
#  Low Value & Slow Moving Products               1.0         0.006897
#
#                                     NewRepeatConversionRatio  \
#  Hero Products                                      0.048466
#  High Repeat Products                               1.000000
#  New Business Products                              0.000000
#  High Value & Slow Moving Products                  0.000000
#  Low Value & Slow Moving Products                   0.000000
#
#                                     Total_Order_Value  NewOrders  ASPXQpC  \
#  Hero Products                              172775.00        709   4048.0
#  High Repeat Products                         1100.00          1    550.0
#  New Business Products                       51623.00         52   5097.0
#  High Value & Slow Moving Products               0.00          0      0.0
#  Low Value & Slow Moving Products             2985.85          1   2980.0
#
#                                     Order_Count  \
#  Hero Products                              777
#  High Repeat Products                         2
#  New Business Products                       85
#  High Value & Slow Moving Products            0
#  Low Value & Slow Moving Products             6
#
#                                                                             Top10SKUs  \
#  Hero Products                      [Cabernet Sauvignon - Wine Barrel Aged Coffee ...
#  High Repeat Products               South Indian Traditional Filter Coffee - Mediu...
#  New Business Products              [Cabernet Sauvignon - Wine Barrel Aged Coffee ...
#  High Value & Slow Moving Products                                                  0
#  Low Value & Slow Moving Products   [Mysore Nuggets - Speciality Blend - Espresso ...
#
#                                                                          Bottom10SKUs  \
#  Hero Products                      [Cabernet Sauvignon - Wine Barrel Aged Coffee ...
#  High Repeat Products                                                              []
#  New Business Products              [Cabernet Sauvignon - Wine Barrel Aged Coffee ...
#  High Value & Slow Moving Products                                                  0
#  Low Value & Slow Moving Products   [Mysore Nuggets - Speciality Blend - Espresso ...
#
#                                     AOVContribution  ProductCountMix  \
#  Hero Products                           198.591954         0.250000
#  High Repeat Products                      1.264368         0.083333
#  New Business Products                    59.336782         0.250000
#  High Value & Slow Moving Products         0.000000         0.000000
#  Low Value & Slow Moving Products          3.432011         0.416667
#
#                                     OrdersMix  UsersMix  AOVContribution(%)  \
#  Hero Products                       0.893103  0.889163            0.756180
#  High Repeat Products                0.002299  0.001232            0.004814
#  New Business Products               0.097701  0.103448            0.225937
#  High Value & Slow Moving Products   0.000000  0.000000            0.000000
#  Low Value & Slow Moving Products    0.006897  0.006158            0.013068
#
#                                     OrderPerSKU
#  Hero Products                       259.000000
#  High Repeat Products                  2.000000
#  New Business Products                28.333333
#  High Value & Slow Moving Products     0.000000
#  Low Value & Slow Moving Products      1.200000  ,
#  '20-w40':                                    ProductCount  Orders  Total_Quantity  \
#  Hero Products                                 6     861             861
#  High Repeat Products                          2       2               2
#  New Business Products                         4      32              32
#  High Value & Slow Moving Products             0       0               0
#  Low Value & Slow Moving Products              9       9               9
#
#                                     Users  AverageSellingPrice  \
#  Hero Products                        804          1332.666667
#  High Repeat Products                   2          1164.500000
#  New Business Products                 31           872.250000
#  High Value & Slow Moving Products      0             0.000000
#  Low Value & Slow Moving Products       9           597.222222
#
#                                     QuantityperCart  CartPenetration  \
#  Hero Products                                  1.0         0.954545
#  High Repeat Products                           1.0         0.002217
#  New Business Products                          1.0         0.035477
#  High Value & Slow Moving Products              0.0         0.000000
#  Low Value & Slow Moving Products               1.0         0.009978
#
#                                     NewRepeatConversionRatio  \
#  Hero Products                                      0.188862
#  High Repeat Products                               0.000000
#  New Business Products                              0.000000
#  High Value & Slow Moving Products                  0.000000
#  Low Value & Slow Moving Products                   0.000000
#
#                                     Total_Order_Value  NewOrders  ASPXQpC  \
#  Hero Products                              234755.20        767   7996.0
#  High Repeat Products                         1756.30          2   2329.0
#  New Business Products                       18611.84         21   3489.0
#  High Value & Slow Moving Products               0.00          0      0.0
#  Low Value & Slow Moving Products             5253.50          6   5375.0
#
#                                     Order_Count  \
#  Hero Products                              861
#  High Repeat Products                         2
#  New Business Products                       32
#  High Value & Slow Moving Products            0
#  Low Value & Slow Moving Products             9
#
#                                                                             Top10SKUs  \
#  Hero Products                      [Cabernet Sauvignon - Wine Barrel Aged Coffee ...
#  High Repeat Products               [Cabernet Sauvignon - Wine Barrel Aged Coffee ...
#  New Business Products              [South Indian Traditional Filter Coffee - Dark...
#  High Value & Slow Moving Products                                                  0
#  Low Value & Slow Moving Products   [Thogurihunkal Estate Coffee - Aeropress / 250...
#
#                                                                          Bottom10SKUs  \
#  Hero Products                      [Cabernet Sauvignon - Wine Barrel Aged Coffee ...
#  High Repeat Products               Cabernet Sauvignon - Wine Barrel Aged Coffee -...
#  New Business Products              [South Indian Traditional Filter Coffee - Dark...
#  High Value & Slow Moving Products                                                  0
#  Low Value & Slow Moving Products   [Thogurihunkal Estate Coffee - Aeropress / 250...
#
#                                     AOVContribution  ProductCountMix  \
#  Hero Products                           259.684956         0.285714
#  High Repeat Products                      1.942810         0.095238
#  New Business Products                    20.588319         0.190476
#  High Value & Slow Moving Products         0.000000         0.000000
#  Low Value & Slow Moving Products          5.811394         0.428571
#
#                                     OrdersMix  UsersMix  AOVContribution(%)  \
#  Hero Products                       0.952434  0.950355            0.901598
#  High Repeat Products                0.002212  0.002364            0.006745
#  New Business Products               0.035398  0.036643            0.071480
#  High Value & Slow Moving Products   0.000000  0.000000            0.000000
#  Low Value & Slow Moving Products    0.009956  0.010638            0.020177
#
#                                     OrderPerSKU
#  Hero Products                            143.5
#  High Repeat Products                       1.0
#  New Business Products                      8.0
#  High Value & Slow Moving Products          0.0
#  Low Value & Slow Moving Products           1.0  ,
#  '20-w41':                                    ProductCount  Orders  Total_Quantity  \
#  Hero Products                                 7     863             864
#  High Repeat Products                          4       4               4
#  New Business Products                         7      77              77
#  High Value & Slow Moving Products             2       2               2
#  Low Value & Slow Moving Products              8       8               8
#
#                                     Users  AverageSellingPrice  \
#  Hero Products                        803          1056.714286
#  High Repeat Products                   4           596.250000
#  New Business Products                 75           886.857143
#  High Value & Slow Moving Products      2          1374.500000
#  Low Value & Slow Moving Products       8           608.750000
#
#                                     QuantityperCart  CartPenetration  \
#  Hero Products                             1.000193         0.907466
#  High Repeat Products                      1.000000         0.004206
#  New Business Products                     1.000000         0.080967
#  High Value & Slow Moving Products         1.000000         0.002103
#  Low Value & Slow Moving Products          1.000000         0.008412
#
#                                     NewRepeatConversionRatio  \
#  Hero Products                                      0.173623
#  High Repeat Products                               0.000000
#  New Business Products                              0.000000
#  High Value & Slow Moving Products                  0.000000
#  Low Value & Slow Moving Products                   0.000000
#
#                                     Total_Order_Value  NewOrders      ASPXQpC  \
#  Hero Products                              236725.20        772  7397.877193
#  High Repeat Products                         2205.00          4  2385.000000
#  New Business Products                       44360.83         52  6208.000000
#  High Value & Slow Moving Products            2239.30          2  2749.000000
#  Low Value & Slow Moving Products             4748.50          4  4870.000000
#
#                                     Order_Count  \
#  Hero Products                              863
#  High Repeat Products                         4
#  New Business Products                       77
#  High Value & Slow Moving Products            2
#  Low Value & Slow Moving Products             8
#
#                                                                             Top10SKUs  \
#  Hero Products                      [Baba Budangiri Estate Coffee - Cold Brew / 25...
#  High Repeat Products               [Thippanahalli Estate Coffee - Moka Pot / 250 ...
#  New Business Products              [Cabernet Sauvignon - Wine Barrel Aged Coffee ...
#  High Value & Slow Moving Products  [Cabernet Sauvignon - Wine Barrel Aged Coffee ...
#  Low Value & Slow Moving Products   [Thogurihunkal Estate Coffee - Aeropress / 250...
#
#                                                                          Bottom10SKUs  \
#  Hero Products                      [Baba Budangiri Estate Coffee - Cold Brew / 25...
#  High Repeat Products               [Thippanahalli Estate Coffee - Moka Pot / 250 ...
#  New Business Products              [Cabernet Sauvignon - Wine Barrel Aged Coffee ...
#  High Value & Slow Moving Products  Cabernet Sauvignon - Wine Barrel Aged Coffee -...
#  Low Value & Slow Moving Products   [Thogurihunkal Estate Coffee - Aeropress / 250...
#
#                                     AOVContribution  ProductCountMix  \
#  Hero Products                           248.139623         0.250000
#  High Repeat Products                      2.311321         0.142857
#  New Business Products                    46.499822         0.250000
#  High Value & Slow Moving Products         2.347275         0.071429
#  Low Value & Slow Moving Products          4.977463         0.285714
#
#                                     OrdersMix  UsersMix  AOVContribution(%)  \
#  Hero Products                       0.904612  0.900224            0.815510
#  High Repeat Products                0.004193  0.004484            0.007596
#  New Business Products               0.080713  0.084081            0.152821
#  High Value & Slow Moving Products   0.002096  0.002242            0.007714
#  Low Value & Slow Moving Products    0.008386  0.008969            0.016358
#
#                                     OrderPerSKU
#  Hero Products                       123.285714
#  High Repeat Products                  1.000000
#  New Business Products                11.000000
#  High Value & Slow Moving Products     1.000000
#  Low Value & Slow Moving Products      1.000000  ,
#  '20-w42':                                    ProductCount  Orders  Total_Quantity  \
#  Hero Products                                11     998             999
#  High Repeat Products                          3       3               3
#  New Business Products                         7      68              68
#  High Value & Slow Moving Products             2       2               2
#  Low Value & Slow Moving Products             13      13              13
#
#                                     Users  AverageSellingPrice  \
#  Hero Products                        936           984.181818
#  High Repeat Products                   3           956.333333
#  New Business Products                 66          1172.285714
#  High Value & Slow Moving Products      2          1599.000000
#  Low Value & Slow Moving Products      13           690.384615
#
#                                     QuantityperCart  CartPenetration  \
#  Hero Products                              1.00012         0.924074
#  High Repeat Products                       1.00000         0.002778
#  New Business Products                      1.00000         0.062963
#  High Value & Slow Moving Products          1.00000         0.001852
#  Low Value & Slow Moving Products           1.00000         0.012037
#
#                                     NewRepeatConversionRatio  \
#  Hero Products                                      0.132264
#  High Repeat Products                               0.333333
#  New Business Products                              0.000000
#  High Value & Slow Moving Products                  0.000000
#  Low Value & Slow Moving Products                   0.000000
#
#                                     Total_Order_Value  NewOrders       ASPXQpC  \
#  Hero Products                              313226.40        884  10826.859788
#  High Repeat Products                         2242.30          3   2869.000000
#  New Business Products                       38705.32         50   8206.000000
#  High Value & Slow Moving Products               2.00          0   3198.000000
#  Low Value & Slow Moving Products             8853.50          7   8975.000000
#
#                                     Order_Count  \
#  Hero Products                              998
#  High Repeat Products                         3
#  New Business Products                       68
#  High Value & Slow Moving Products            2
#  Low Value & Slow Moving Products            13
#
#                                                                             Top10SKUs  \
#  Hero Products                      [Baba Budangiri Estate Coffee - Cold Brew / 25...
#  High Repeat Products               [Thippanahalli Estate Coffee - Moka Pot / 250 ...
#  New Business Products              [Cabernet Sauvignon - Wine Barrel Aged Coffee ...
#  High Value & Slow Moving Products  [Amrut - Whiskey Barrel Aged Coffee - French P...
#  Low Value & Slow Moving Products   [Thogurihunkal Estate Coffee - Aeropress / 250...
#
#                                                                          Bottom10SKUs  \
#  Hero Products                      [Baba Budangiri Estate Coffee - Espresso / 250...
#  High Repeat Products               [Thippanahalli Estate Coffee - Moka Pot / 250 ...
#  New Business Products              [Cabernet Sauvignon - Wine Barrel Aged Coffee ...
#  High Value & Slow Moving Products  Amrut - Whiskey Barrel Aged Coffee - French Pr...
#  Low Value & Slow Moving Products   [Mysore Nuggets - Speciality Blend - Espresso ...
#
#                                     AOVContribution  ProductCountMix  \
#  Hero Products                           288.954244         0.305556
#  High Repeat Products                      2.068542         0.083333
#  New Business Products                    35.706015         0.194444
#  High Value & Slow Moving Products         0.001845         0.055556
#  Low Value & Slow Moving Products          8.167435         0.361111
#
#                                     OrdersMix  UsersMix  AOVContribution(%)  \
#  Hero Products                       0.920664  0.917647            0.862812
#  High Repeat Products                0.002768  0.002941            0.006177
#  New Business Products               0.062731  0.064706            0.106618
#  High Value & Slow Moving Products   0.001845  0.001961            0.000006
#  Low Value & Slow Moving Products    0.011993  0.012745            0.024388
#
#                                     OrderPerSKU
#  Hero Products                        90.727273
#  High Repeat Products                  1.000000
#  New Business Products                 9.714286
#  High Value & Slow Moving Products     1.000000
#  Low Value & Slow Moving Products      1.000000  ,
#  '20-w43':                                    ProductCount  Orders  Total_Quantity  \
#  Hero Products                                13    1234            1236
#  High Repeat Products                          3       5               6
#  New Business Products                         5     105             105
#  High Value & Slow Moving Products             0       0               0
#  Low Value & Slow Moving Products             16      20              20
#
#                                     Users  AverageSellingPrice  \
#  Hero Products                       1164          1161.000000
#  High Repeat Products                   3           944.666667
#  New Business Products                102          1202.400000
#  High Value & Slow Moving Products      0             0.000000
#  Low Value & Slow Moving Products      20           699.062500
#
#                                     QuantityperCart  CartPenetration  \
#  Hero Products                             1.001609         0.907353
#  High Repeat Products                      1.111111         0.003676
#  New Business Products                     1.000000         0.077206
#  High Value & Slow Moving Products         0.000000         0.000000
#  Low Value & Slow Moving Products          1.000000         0.014706
#
#                                     NewRepeatConversionRatio  \
#  Hero Products                                      0.091259
#  High Repeat Products                               0.666667
#  New Business Products                              0.000000
#  High Value & Slow Moving Products                  0.000000
#  Low Value & Slow Moving Products                   0.000000
#
#                                     Total_Order_Value  NewOrders       ASPXQpC  \
#  Hero Products                              459076.69       1069  15104.636214
#  High Repeat Products                         3695.80          3   3017.333333
#  New Business Products                       65050.83         74   6012.000000
#  High Value & Slow Moving Products               0.00          0      0.000000
#  Low Value & Slow Moving Products            13309.98         13  11185.000000
#
#                                     Order_Count  \
#  Hero Products                             1234
#  High Repeat Products                         5
#  New Business Products                      105
#  High Value & Slow Moving Products            0
#  Low Value & Slow Moving Products            20
#
#                                                                             Top10SKUs  \
#  Hero Products                      [Baba Budangiri Estate Coffee - Espresso / 250...
#  High Repeat Products               [Thogurihunkal Estate Coffee - Moka Pot / 250 ...
#  New Business Products              [Amrut - Whiskey Barrel Aged Coffee - Whole Be...
#  High Value & Slow Moving Products                                                  0
#  Low Value & Slow Moving Products   [Thogurihunkal Estate Coffee - Aeropress / 250...
#
#                                                                          Bottom10SKUs  \
#  Hero Products                      [Baba Budangiri Estate Coffee - Pour Over / 25...
#  High Repeat Products               [Thogurihunkal Estate Coffee - Moka Pot / 250 ...
#  New Business Products              [Amrut - Whiskey Barrel Aged Coffee - Whole Be...
#  High Value & Slow Moving Products                                                  0
#  Low Value & Slow Moving Products   [Mysore Nuggets - Speciality Blend - Aeropress...
#
#                                     AOVContribution  ProductCountMix  \
#  Hero Products                           336.566488         0.351351
#  High Repeat Products                      2.709531         0.081081
#  New Business Products                    47.691224         0.135135
#  High Value & Slow Moving Products         0.000000         0.000000
#  Low Value & Slow Moving Products          9.758050         0.432432
#
#                                     OrdersMix  UsersMix  AOVContribution(%)  \
#  Hero Products                       0.904692  0.903026            0.848362
#  High Repeat Products                0.003666  0.002327            0.006830
#  New Business Products               0.076979  0.079131            0.120212
#  High Value & Slow Moving Products   0.000000  0.000000            0.000000
#  Low Value & Slow Moving Products    0.014663  0.015516            0.024596
#
#                                     OrderPerSKU
#  Hero Products                        94.923077
#  High Repeat Products                  1.666667
#  New Business Products                21.000000
#  High Value & Slow Moving Products     0.000000
#  Low Value & Slow Moving Products      1.250000  ,
#  '20-w44':                                    ProductCount  Orders  Total_Quantity  \
#  Hero Products                                14    1349            1352
#  High Repeat Products                          4       4               4
#  New Business Products                         5     130             130
#  High Value & Slow Moving Products             1       1               1
#  Low Value & Slow Moving Products             15      22              22
#
#                                     Users  AverageSellingPrice  \
#  Hero Products                       1269          1117.357143
#  High Repeat Products                   4           863.500000
#  New Business Products                127          1202.400000
#  High Value & Slow Moving Products      1          2220.000000
#  Low Value & Slow Moving Products      22           706.666667
#
#                                     QuantityperCart  CartPenetration  \
#  Hero Products                             1.024953         0.898136
#  High Repeat Products                      1.000000         0.002663
#  New Business Products                     1.000000         0.086551
#  High Value & Slow Moving Products         1.000000         0.000666
#  Low Value & Slow Moving Products          1.000000         0.014647
#
#                                     NewRepeatConversionRatio  \
#  Hero Products                                      0.191497
#  High Repeat Products                               0.250000
#  New Business Products                              0.000000
#  High Value & Slow Moving Products                  0.000000
#  Low Value & Slow Moving Products                   0.000000
#
#                                     Total_Order_Value  NewOrders       ASPXQpC  \
#  Hero Products                              528561.69       1155  15835.270133
#  High Repeat Products                         2885.80          4   3454.000000
#  New Business Products                       88720.83         97   6012.000000
#  High Value & Slow Moving Products            1776.00          1   2220.000000
#  Low Value & Slow Moving Products            14942.98         15  10600.000000
#
#                                     Order_Count  \
#  Hero Products                             1349
#  High Repeat Products                         4
#  New Business Products                      130
#  High Value & Slow Moving Products            1
#  Low Value & Slow Moving Products            22
#
#                                                                             Top10SKUs  \
#  Hero Products                      [Baba Budangiri Estate Coffee - Pour Over / 25...
#  High Repeat Products               [Thippanahalli Estate Coffee - French Press / ...
#  New Business Products              [Amrut - Whiskey Barrel Aged Coffee - Whole Be...
#  High Value & Slow Moving Products  Thippanahalli Estate Coffee - Whole Beans / 10...
#  Low Value & Slow Moving Products   [Thogurihunkal Estate Coffee - Aeropress / 250...
#
#                                                                          Bottom10SKUs  \
#  Hero Products                      [Baba Budangiri Estate Coffee - French Press /...
#  High Repeat Products               [Thippanahalli Estate Coffee - French Press / ...
#  New Business Products              [Amrut - Whiskey Barrel Aged Coffee - Whole Be...
#  High Value & Slow Moving Products                                                 []
#  Low Value & Slow Moving Products   [Mysore Nuggets - Speciality Blend - Pour Over...
#
#                                     AOVContribution  ProductCountMix  \
#  Hero Products                           350.970578         0.358974
#  High Repeat Products                      1.916202         0.102564
#  New Business Products                    58.911574         0.128205
#  High Value & Slow Moving Products         1.179283         0.025641
#  Low Value & Slow Moving Products          9.922297         0.384615
#
#                                     OrdersMix  UsersMix  AOVContribution(%)  \
#  Hero Products                       0.895750  0.891778            0.829914
#  High Repeat Products                0.002656  0.002811            0.004531
#  New Business Products               0.086321  0.089248            0.139304
#  High Value & Slow Moving Products   0.000664  0.000703            0.002789
#  Low Value & Slow Moving Products    0.014608  0.015460            0.023463
#
#                                     OrderPerSKU
#  Hero Products                        96.357143
#  High Repeat Products                  1.000000
#  New Business Products                26.000000
#  High Value & Slow Moving Products     1.000000
#  Low Value & Slow Moving Products      1.466667  ,
#  '20-w45':                                    ProductCount  Orders  Total_Quantity  \
#  Hero Products                                15    1524            1528
#  High Repeat Products                          5       7               9
#  New Business Products                         6      85             117
#  High Value & Slow Moving Products             2       2               2
#  Low Value & Slow Moving Products             15      25              25
#
#                                     Users  AverageSellingPrice  \
#  Hero Products                       1435          1149.466667
#  High Repeat Products                   5           909.800000
#  New Business Products                 80          1107.000000
#  High Value & Slow Moving Products      2          2685.000000
#  Low Value & Slow Moving Products      24           698.333333
#
#                                     QuantityperCart  CartPenetration  \
#  Hero Products                             1.025844         0.933824
#  High Repeat Products                      1.200000         0.004289
#  New Business Products                     2.729167         0.052083
#  High Value & Slow Moving Products         1.000000         0.001225
#  Low Value & Slow Moving Products          1.000000         0.015319
#
#                                     NewRepeatConversionRatio  \
#  Hero Products                                      0.186433
#  High Repeat Products                               0.600000
#  New Business Products                              0.000000
#  High Value & Slow Moving Products                  0.000000
#  Low Value & Slow Moving Products                   0.000000
#
#                                     Total_Order_Value  NewOrders       ASPXQpC  \
#  Hero Products                          646023.690000       1299  17503.218061
#  High Repeat Products                     5778.561042          5   5156.500000
#  New Business Products                  108624.368958         54  23231.625000
#  High Value & Slow Moving Products        4296.000000          2   5370.000000
#  Low Value & Slow Moving Products        16465.980000         17  10475.000000
#
#                                     Order_Count  \
#  Hero Products                             1524
#  High Repeat Products                         7
#  New Business Products                       85
#  High Value & Slow Moving Products            2
#  Low Value & Slow Moving Products            25
#
#                                                                             Top10SKUs  \
#  Hero Products                      [Amrut - Whiskey Barrel Aged Coffee - Pour Ove...
#  High Repeat Products               [Thippanahalli Estate Coffee - Pour Over / 250...
#  New Business Products              [Blonde Caramel - Speciality Blend - Cold Brew...
#  High Value & Slow Moving Products  [Amrut - Whiskey Barrel Aged Coffee - French P...
#  Low Value & Slow Moving Products   [South Indian Traditional Filter Coffee - Dark...
#
#                                                                          Bottom10SKUs  \
#  Hero Products                      [Baba Budangiri Estate Coffee - French Press /...
#  High Repeat Products               [Thippanahalli Estate Coffee - Pour Over / 250...
#  New Business Products              [Blonde Caramel - Speciality Blend - Cold Brew...
#  High Value & Slow Moving Products  Amrut - Whiskey Barrel Aged Coffee - French Pr...
#  Low Value & Slow Moving Products   [Mysore Nuggets - Speciality Blend - Pour Over...
#
#                                     AOVContribution  ProductCountMix  \
#  Hero Products                           393.197620         0.348837
#  High Repeat Products                      3.517079         0.116279
#  New Business Products                    66.113432         0.139535
#  High Value & Slow Moving Products         2.614729         0.046512
#  Low Value & Slow Moving Products         10.021899         0.348837
#
#                                     OrdersMix  UsersMix  AOVContribution(%)  \
#  Hero Products                       0.927572  0.928202            0.826975
#  High Repeat Products                0.004260  0.003234            0.007397
#  New Business Products               0.051735  0.051746            0.139050
#  High Value & Slow Moving Products   0.001217  0.001294            0.005499
#  Low Value & Slow Moving Products    0.015216  0.015524            0.021078
#
#                                     OrderPerSKU
#  Hero Products                       101.600000
#  High Repeat Products                  1.400000
#  New Business Products                14.166667
#  High Value & Slow Moving Products     1.000000
#  Low Value & Slow Moving Products      1.666667  ,
#  '20-w46':                                    ProductCount  Orders  Total_Quantity  \
#  Hero Products                                16    1684            1688
#  High Repeat Products                          6       9              11
#  New Business Products                         8     106             138
#  High Value & Slow Moving Products             3       3               3
#  Low Value & Slow Moving Products             16      24              24
#
#                                     Users  AverageSellingPrice  \
#  Hero Products                       1589          1117.000000
#  High Repeat Products                   7          1058.166667
#  New Business Products                 99           977.750000
#  High Value & Slow Moving Products      3          2128.000000
#  Low Value & Slow Moving Products      23           796.562500
#
#                                     QuantityperCart  CartPenetration  \
#  Hero Products                             1.015610         0.929873
#  High Repeat Products                      1.166667         0.004970
#  New Business Products                     1.650144         0.058531
#  High Value & Slow Moving Products         1.000000         0.001657
#  Low Value & Slow Moving Products          1.000000         0.013252
#
#                                     NewRepeatConversionRatio  \
#  Hero Products                                      0.197760
#  High Repeat Products                               0.666667
#  New Business Products                              0.000000
#  High Value & Slow Moving Products                  0.000000
#  Low Value & Slow Moving Products                   0.000000
#
#                                     Total_Order_Value  NewOrders       ASPXQpC  \
#  Hero Products                          748191.490000       1434  18055.458646
#  High Repeat Products                     7847.800000          6   6956.500000
#  New Business Products                  126396.768958         70  16138.637931
#  High Value & Slow Moving Products        5434.200000          2   6384.000000
#  Low Value & Slow Moving Products        17707.741042         16  12745.000000
#
#                                     Order_Count  \
#  Hero Products                             1684
#  High Repeat Products                         9
#  New Business Products                      106
#  High Value & Slow Moving Products            3
#  Low Value & Slow Moving Products            24
#
#                                                                             Top10SKUs  \
#  Hero Products                      [Amrut - Whiskey Barrel Aged Coffee - Pour Ove...
#  High Repeat Products               [Thippanahalli Estate Coffee - Whole Beans / 1...
#  New Business Products              [Amrut - Whiskey Barrel Aged Coffee - Whole Be...
#  High Value & Slow Moving Products  [Amrut - Whiskey Barrel Aged Coffee - French P...
#  Low Value & Slow Moving Products   [South Indian Traditional Filter Coffee - Dark...
#
#                                                                          Bottom10SKUs  \
#  Hero Products                      [Easy Brew - Cold Brew Bags (Pack of 4), Baba ...
#  High Repeat Products               [Thippanahalli Estate Coffee - Whole Beans / 1...
#  New Business Products              [Amrut - Whiskey Barrel Aged Coffee - Whole Be...
#  High Value & Slow Moving Products  [Amrut - Whiskey Barrel Aged Coffee - French P...
#  Low Value & Slow Moving Products   [Mysore Nuggets - Speciality Blend - Pour Over...
#
#                                     AOVContribution  ProductCountMix  \
#  Hero Products                           409.743423         0.326531
#  High Repeat Products                      4.297809         0.122449
#  New Business Products                    69.220574         0.163265
#  High Value & Slow Moving Products         2.976013         0.061224
#  Low Value & Slow Moving Products          9.697558         0.326531
#
#                                     OrdersMix  UsersMix  AOVContribution(%)  \
#  Hero Products                       0.922234  0.923300            0.826203
#  High Repeat Products                0.004929  0.004067            0.008666
#  New Business Products               0.058050  0.057525            0.139576
#  High Value & Slow Moving Products   0.001643  0.001743            0.006001
#  Low Value & Slow Moving Products    0.013143  0.013364            0.019554
#
#                                     OrderPerSKU
#  Hero Products                           105.25
#  High Repeat Products                      1.50
#  New Business Products                    13.25
#  High Value & Slow Moving Products         1.00
#  Low Value & Slow Moving Products          1.50  ,
#  '20-w47':                                    ProductCount  Orders  Total_Quantity  \
#  Hero Products                                18    1897            1902
#  High Repeat Products                          4       6               8
#  New Business Products                         7      90             121
#  High Value & Slow Moving Products             5       5               5
# ...
#  Hero Products                      [Irish Cold Brew - Easy Brew Cold Brew Bags - ...
#  High Repeat Products               [Thippanahalli Estate Coffee - Turkish Coffee ...
#  New Business Products              [Thogurihunkal Estate Coffee - Whole Beans / 2...
#  High Value & Slow Moving Products  [Chemex Coffee Maker - Wooden Collar / 3 Cups,...
#  Low Value & Slow Moving Products   [Tanzania Coffee (From Mt Kilimanjaro) - Kalit...
#
#                                     AOVContribution  ProductCountMix  \
#  Hero Products                           204.998751         0.284934
#  High Repeat Products                      6.199252         0.155022
#  New Business Products                   262.795755         0.215066
#  High Value & Slow Moving Products         7.054737         0.139738
#  Low Value & Slow Moving Products          3.992993         0.205240
#
#                                     OrdersMix  UsersMix  AOVContribution(%)  \
#  Hero Products                       0.427483  0.371336            0.422642
#  High Repeat Products                0.004696  0.005495            0.012781
#  New Business Products               0.559231  0.612895            0.541801
#  High Value & Slow Moving Products   0.002975  0.003537            0.014545
#  Low Value & Slow Moving Products    0.005615  0.006737            0.008232
#
#                                     OrderPerSKU
#  Hero Products                       151.383142
#  High Repeat Products                  3.056338
#  New Business Products               262.375635
#  High Value & Slow Moving Products     2.148438
#  Low Value & Slow Moving Products      2.760638  ,
#  '23-w52':                                    ProductCount  Orders  Total_Quantity  \
#  Hero Products                               261   39607           42962
#  High Repeat Products                        142     436             465
#  New Business Products                       197   52092           56381
#  High Value & Slow Moving Products           128     277             305
#  Low Value & Slow Moving Products            189     520             563
#
#                                     Users  AverageSellingPrice  \
#  Hero Products                      27568           989.710082
#  High Repeat Products                 409          1553.032478
#  New Business Products              45671          1157.863801
#  High Value & Slow Moving Products    264          2583.647693
#  Low Value & Slow Moving Products     500           931.637231
#
#                                     QuantityperCart  CartPenetration  \
#  Hero Products                             1.094027         0.545761
#  High Repeat Products                      1.059993         0.006008
#  New Business Products                     1.097490         0.717797
#  High Value & Slow Moving Products         1.076628         0.003817
#  Low Value & Slow Moving Products          1.063964         0.007165
#
#                                     NewRepeatConversionRatio  \
#  Hero Products                                      0.401423
#  High Repeat Products                               0.738850
#  New Business Products                              0.150646
#  High Value & Slow Moving Products                  0.015584
#  Low Value & Slow Moving Products                   0.029026
#
#                                     Total_Order_Value  NewOrders  \
#  Hero Products                           1.900787e+07      16575
#  High Repeat Products                    5.746086e+05        288
#  New Business Products                   2.440254e+07      38809
#  High Value & Slow Moving Products       6.557641e+05        137
#  Low Value & Slow Moving Products        3.699704e+05        303
#
#                                           ASPXQpC  Order_Count  \
#  Hero Products                      285820.545116        39607
#  High Repeat Products               230993.208152          436
#  New Business Products              252956.141727        52092
#  High Value & Slow Moving Products  352494.048413          277
#  Low Value & Slow Moving Products   187538.209107          520
#
#                                                                             Top10SKUs  \
#  Hero Products                      [Peaberry Coffee - Medium Roast - Whole Beans ...
#  High Repeat Products               [Chemex Filter Paper for 3 Cups - White, Holid...
#  New Business Products              [Dark Roast - Coffee Sample Pack - Turkish Cof...
#  High Value & Slow Moving Products  [Kalita Wave Dripper Series (Stainless Steel o...
#  Low Value & Slow Moving Products   [Dark Roast - Coffee Sample Pack - Hario V60, ...
#
#                                                                          Bottom10SKUs  \
#  Hero Products                      [Papáia: Papaya Fermened Coffee - Cold Brew / ...
#  High Repeat Products               [Thippanahalli Estate Coffee - Turkish Coffee ...
#  New Business Products              [Hario V60 Plastic Dripper - White, Tanzania C...
#  High Value & Slow Moving Products  [Chemex Coffee Maker - Wooden Collar / 3 Cups,...
#  Low Value & Slow Moving Products   [Tanzania Coffee (From Mt Kilimanjaro) - Cheme...
#
#                                     AOVContribution  ProductCountMix  \
#  Hero Products                           204.535240         0.284624
#  High Repeat Products                      6.183108         0.154853
#  New Business Products                   262.584940         0.214831
#  High Value & Slow Moving Products         7.056386         0.139586
#  Low Value & Slow Moving Products          3.981087         0.206107
#
#                                     OrdersMix  UsersMix  AOVContribution(%)  \
#  Hero Products                       0.426193  0.370478            0.422296
#  High Repeat Products                0.004692  0.005496            0.012766
#  New Business Products               0.560539  0.613759            0.542149
#  High Value & Slow Moving Products   0.002981  0.003548            0.014569
#  Low Value & Slow Moving Products    0.005595  0.006719            0.008220
#
#                                     OrderPerSKU
#  Hero Products                       151.750958
#  High Repeat Products                  3.070423
#  New Business Products               264.426396
#  High Value & Slow Moving Products     2.164062
#  Low Value & Slow Moving Products      2.751323  ,
#  '23-w53':                                    ProductCount  Orders  Total_Quantity  \
#  Hero Products                               261   39628           42988
#  High Repeat Products                        142     437             466
#  New Business Products                       197   52157           56448
#  High Value & Slow Moving Products           128     277             305
#  Low Value & Slow Moving Products            189     521             564
#
#                                     Users  AverageSellingPrice  \
#  Hero Products                      27578           989.712962
#  High Repeat Products                 409          1553.032478
#  New Business Products              45714          1157.848788
#  High Value & Slow Moving Products    264          2583.647693
#  Low Value & Slow Moving Products     501           931.690141
#
#                                     QuantityperCart  CartPenetration  \
#  Hero Products                             1.094054         0.545457
#  High Repeat Products                      1.059993         0.006015
#  New Business Products                     1.097466         0.717912
#  High Value & Slow Moving Products         1.076628         0.003813
#  Low Value & Slow Moving Products          1.063083         0.007171
#
#                                     NewRepeatConversionRatio  \
#  Hero Products                                      0.401512
#  High Repeat Products                               0.738850
#  New Business Products                              0.150651
#  High Value & Slow Moving Products                  0.015584
#  Low Value & Slow Moving Products                   0.029026
#
#                                     Total_Order_Value  NewOrders  \
#  Hero Products                           1.901738e+07      16576
#  High Repeat Products                    5.758686e+05        288
#  New Business Products                   2.442215e+07      38842
#  High Value & Slow Moving Products       6.557641e+05        137
#  Low Value & Slow Moving Products        3.710234e+05        303
#
#                                           ASPXQpC  Order_Count  \
#  Hero Products                      285827.784783        39628
#  High Repeat Products               230993.208152          437
#  New Business Products              252946.372231        52157
#  High Value & Slow Moving Products  352494.048413          277
#  Low Value & Slow Moving Products   187267.375774          521
#
#                                                                             Top10SKUs  \
#  Hero Products                      [Peaberry Coffee - Medium Roast - Whole Beans ...
#  High Repeat Products               [Chemex Filter Paper for 3 Cups - White, Holid...
#  New Business Products              [Dark Roast - Coffee Sample Pack - Turkish Cof...
#  High Value & Slow Moving Products  [Kalita Wave Dripper Series (Stainless Steel o...
#  Low Value & Slow Moving Products   [Dark Roast - Coffee Sample Pack - Hario V60, ...
#
#                                                                          Bottom10SKUs  \
#  Hero Products                      [Annanas: PineApple Fermented Coffee - Cold Br...
#  High Repeat Products               [Thippanahalli Estate Coffee - Turkish Coffee ...
#  New Business Products              [Hario V60 Plastic Dripper - White, Tanzania C...
#  High Value & Slow Moving Products  [Chemex Coffee Maker - Wooden Collar / 3 Cups,...
#  Low Value & Slow Moving Products   [Tanzania Coffee (From Mt Kilimanjaro) - Cheme...
#
#                                     AOVContribution  ProductCountMix  \
#  Hero Products                           204.443957         0.284624
#  High Repeat Products                      6.190804         0.154853
#  New Business Products                   262.547330         0.214831
#  High Value & Slow Moving Products         7.049710         0.139586
#  Low Value & Slow Moving Products          3.988641         0.206107
#
#                                     OrdersMix  UsersMix  AOVContribution(%)  \
#  Hero Products                       0.426016  0.370344            0.422213
#  High Repeat Products                0.004698  0.005492            0.012785
#  New Business Products               0.560707  0.613891            0.542206
#  High Value & Slow Moving Products   0.002978  0.003545            0.014559
#  Low Value & Slow Moving Products    0.005601  0.006728            0.008237
#
#                                     OrderPerSKU
#  Hero Products                       151.831418
#  High Repeat Products                  3.077465
#  New Business Products               264.756345
#  High Value & Slow Moving Products     2.164062
#  Low Value & Slow Moving Products      2.756614  ,
#  '24-w00':                                    ProductCount  Orders  Total_Quantity  \
#  Hero Products                               261   39677           43063
#  High Repeat Products                        142     439             468
#  New Business Products                       197   52291           56584
#  High Value & Slow Moving Products           128     277             305
#  Low Value & Slow Moving Products            189     521             564
#
#                                     Users  AverageSellingPrice  \
#  Hero Products                      27607           997.899372
#  High Repeat Products                 411          1553.032478
#  New Business Products              45819          1146.739057
#  High Value & Slow Moving Products    264          2583.647693
#  Low Value & Slow Moving Products     501           931.690141
#
#                                     QuantityperCart  CartPenetration  \
#  Hero Products                             1.094857         0.545021
#  High Repeat Products                      1.059993         0.006030
#  New Business Products                     1.096736         0.718293
#  High Value & Slow Moving Products         1.076628         0.003805
#  Low Value & Slow Moving Products          1.063083         0.007157
#
#                                     NewRepeatConversionRatio  \
#  Hero Products                                      0.402269
#  High Repeat Products                               0.737676
#  New Business Products                              0.150876
#  High Value & Slow Moving Products                  0.015584
#  Low Value & Slow Moving Products                   0.029026
#
#                                     Total_Order_Value  NewOrders  \
#  Hero Products                           1.907240e+07      16578
#  High Repeat Products                    5.767947e+05        289
#  New Business Products                   2.443329e+07      38920
#  High Value & Slow Moving Products       6.557641e+05        137
#  Low Value & Slow Moving Products        3.710234e+05        303
#
#                                           ASPXQpC  Order_Count  \
#  Hero Products                      288267.987692        39677
#  High Repeat Products               230993.208152          439
#  New Business Products              250480.010781        52291
#  High Value & Slow Moving Products  352494.048413          277
#  Low Value & Slow Moving Products   187267.375774          521
#
#                                                                             Top10SKUs  \
#  Hero Products                      [Single Malt Whiskey Barrel Aged Coffee - Home...
#  High Repeat Products               [Chemex Filter Paper for 3 Cups - White, Singl...
#  New Business Products              [Dark Roast - Coffee Sample Pack - Turkish Cof...
#  High Value & Slow Moving Products  [Kalita Wave Dripper Series (Stainless Steel o...
#  Low Value & Slow Moving Products   [Dark Roast - Coffee Sample Pack - Hario V60, ...
#
#                                                                          Bottom10SKUs  \
#  Hero Products                      [Annanas: PineApple Fermented Coffee - Cold Br...
#  High Repeat Products               [Aerolatte Steam Free Milk Frother To-Go with ...
#  New Business Products              [Peaberry Coffee - Medium Roast - Turkish Coff...
#  High Value & Slow Moving Products  [Chemex Coffee Maker - Wooden Collar / 3 Cups,...
#  Low Value & Slow Moving Products   [Tanzania Coffee (From Mt Kilimanjaro) - Cheme...
#
#                                     AOVContribution  ProductCountMix  \
#  Hero Products                           204.628461         0.284624
#  High Repeat Products                      6.188452         0.154853
#  New Business Products                   262.145709         0.214831
#  High Value & Slow Moving Products         7.035718         0.139586
#  Low Value & Slow Moving Products          3.980724         0.206107
#
#                                     OrdersMix  UsersMix  AOVContribution(%)  \
#  Hero Products                       0.425696  0.370057            0.422804
#  High Repeat Products                0.004710  0.005509            0.012787
#  New Business Products               0.561032  0.614179            0.541647
#  High Value & Slow Moving Products   0.002972  0.003539            0.014537
#  Low Value & Slow Moving Products    0.005590  0.006716            0.008225
#
#                                     OrderPerSKU
#  Hero Products                       152.019157
#  High Repeat Products                  3.091549
#  New Business Products               265.436548
#  High Value & Slow Moving Products     2.164062
#  Low Value & Slow Moving Products      2.756614  }

# %%
each_metric_df = {}
ListofCustomerCohortVariables = p1.columns.to_list()
Line_Chart_Variable_List_Product = ['AverageSellingPrice', 'QuantityperCart', 'CartPenetration', 'NewUserRatio', 'ASPXQpC']
Stack_Chart_Variable_List_Product = ['ProductCount', 'Orders', 'AOVContribution', 'Quantity', 'NewOrders', 'NewRepeatConversionRatio', 'Users']
for week, df in productsegstats_weekly.items():
    df.sort_index(inplace=True)

def metric_graph(metric):
  if metric in Line_Chart_Variable_List_Product:
    column_df = pd.DataFrame({week: df[metric].tolist() for week, df in productsegstats_weekly.items()})
    column_df.index = product_cohort_labels
    column_transposed = column_df.transpose()
    insights_table = column_transposed
    each_metric_df[metric] = column_transposed
    weeks = column_transposed.index.to_list()
    for column_name, values in column_transposed.items():
      plt.plot(weeks, values, label=column_name)
    plt.xlabel('Weeks')
    plt.ylabel(metric)
    plt.title(f'{metric}')
    plt.xticks(fontsize=4, rotation=90)
    plt.legend(loc='upper left', bbox_to_anchor=(1,1), title = 'Customer Cohort Lables')
    plt.show()

  if metric in Stack_Chart_Variable_List_Product:
    variable_df = pd.DataFrame({week: df[metric].tolist() for week, df in productsegstats_weekly.items()})
    variable_df.index = product_cohort_labels
    variable_df_transposed = variable_df.transpose()
    each_metric_df[metric] = variable_df_transposed
    insights_table = variable_df_transposed
    graph2 = variable_df_transposed
    graph2.plot(kind='bar', stacked=True, figsize=(8, 4))
    plt.title(f'{metric}')
    plt.xticks(fontsize=4)
    plt.xlabel('Weeks')
    plt.ylabel(metric)
    plt.legend(loc='upper left', bbox_to_anchor=(1,1), title = 'Customer Cohort Lables')
    plt.show()
  return insights_table

output = metric_graph('ProductCount')
output
# Out:
#         Hero Products  High Repeat Products  New Business Products  \
# 20-w37              2                     0                      1
# 20-w38              1                     1                      1
# 20-w39              3                     1                      0
# 20-w40              6                     2                      0
# 20-w41              7                     4                      2
# ...               ...                   ...                    ...
# 23-w50            261                   142                    127
# 23-w51            261                   142                    128
# 23-w52            261                   142                    128
# 23-w53            261                   142                    128
# 24-w00            261                   142                    128
#
#         High Value & Slow Moving Products  Low Value & Slow Moving Products
# 20-w37                                  3                                 1
# 20-w38                                  3                                 3
# 20-w39                                  5                                 3
# 20-w40                                  9                                 4
# 20-w41                                  8                                 7
# ...                                   ...                               ...
# 23-w50                                188                               196
# 23-w51                                188                               197
# 23-w52                                189                               197
# 23-w53                                189                               197
# 24-w00                                189                               197
#
# [176 rows x 5 columns]

# %%
output
# Out:
#         Hero Products  High Repeat Products  New Business Products  \
# 20-w37              2                     0                      1
# 20-w38              1                     1                      1
# 20-w39              3                     1                      0
# 20-w40              6                     2                      0
# 20-w41              7                     4                      2
# ...               ...                   ...                    ...
# 23-w50            261                   142                    127
# 23-w51            261                   142                    128
# 23-w52            261                   142                    128
# 23-w53            261                   142                    128
# 24-w00            261                   142                    128
#
#         High Value & Slow Moving Products  Low Value & Slow Moving Products
# 20-w37                                  3                                 1
# 20-w38                                  3                                 3
# 20-w39                                  5                                 3
# 20-w40                                  9                                 4
# 20-w41                                  8                                 7
# ...                                   ...                               ...
# 23-w50                                188                               196
# 23-w51                                188                               197
# 23-w52                                189                               197
# 23-w53                                189                               197
# 24-w00                                189                               197
#
# [176 rows x 5 columns]

# %%
def metric_cohort_graph(metric, cohort):
    if metric in Line_Chart_Variable_List_Product:
        column_df = pd.DataFrame({week: df[metric].tolist() for week, df in productsegstats_weekly.items()})
        column_df.index = product_cohort_labels
        column_transposed = column_df.transpose()
        each_metric_df[metric] = column_transposed[cohort]  # Select only the specified cohort column

        # Replace zero values with np.nan
        each_metric_df[metric] = np.where(each_metric_df[metric] == 0, np.nan, each_metric_df[metric])

        plt.plot(column_transposed.index, each_metric_df[metric], label=cohort)
        plt.xlabel('Weeks')
        plt.ylabel(metric)
        plt.title(f'Weekly {metric}')
        plt.xticks(fontsize=4, rotation=90)
        plt.legend(loc='upper left', bbox_to_anchor=(1, 1), title='Customer Cohort Labels')
        plt.show()

    if metric in Stack_Chart_Variable_List_Product:
        variable_df = pd.DataFrame({week: df[metric].tolist() for week, df in productsegstats_weekly.items()})
        variable_df.index = product_cohort_labels
        variable_df_transposed = variable_df.transpose()
        each_metric_df[metric] = variable_df_transposed[cohort]  # Select only the specified cohort column

        # Replace zero values with np.nan
        each_metric_df[metric] = np.where(each_metric_df[metric] == 0, np.nan, each_metric_df[metric])

        graph2 = pd.DataFrame({cohort: each_metric_df[metric]})
        graph2.plot(kind='bar', stacked=True, figsize=(8, 4))
        plt.title(f'Weekly {metric}')
        plt.xticks(fontsize=4)
        plt.xlabel('Weeks')
        plt.ylabel(metric)
        plt.legend(loc='upper left', bbox_to_anchor=(1, 1), title='Customer Cohort Labels')
        plt.show()

# Call the function with the specified metric and cohort
result = metric_cohort_graph('AverageSellingPrice', 'Hero Products')
